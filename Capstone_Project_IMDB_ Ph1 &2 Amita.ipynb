# %% [markdown]
# ## Capstone Project - IMDB Dataset
# ### Phase 1 & 2
# ### By: Amita Saini

# %% [markdown]
# ### Phase 1
#
# 1) Webscrape the provided URL  - IMDB dataset:
# https://www.imdb.com/search/title/?genres=action&sort=user_rating,desc&title_type=feature&num_votes=25000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=f11158cc-b50b-4c4d-b0a2-40b32863395b&pf_rd_r=XZ8X52H1R40B7KG5SNZ9&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_1
#
# 2) Store the entire data in two different CSV files as per the given fields:
#
# The first CSV file data contains :
# Sno, Movie Name, Director Name, Duration, year, ratings, Metascore
# Bifurcate the Director field into subfields as per the number of directors of the movie belongs to such as Director1, director2
#
# The second CSV file contains the following:
# Movie Name, stars, votes, Genre, Gross collection, popularity, Certification
# Bifurcate the stars field into 4 subfields as per the number of stars worked in the movie such as star1, star2, star3, star4
# Bifurcate the genre into 3 subfields as per the number of genres the movie belongs to such as :
# Genre1, genre2, genre3

# %%
# Import necessary Libraries

from bs4 import BeautifulSoup
import pandas as pd
import requests
import numpy as np

# %%
url = 'https://www.imdb.com/search/title/?genres=action&sort=user_rating,desc&title_type=feature&num_votes=25000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=f11158cc-b50b-4c4d-b0a2-40b32863395b&pf_rd_r=XZ8X52H1R40B7KG5SNZ9&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_1'

# List to store data for the first CSV
first_csv_data = []

# List to store data for the second CSV
second_csv_data = []

page = 1
while True:
    # Send a GET request to the URL
    response = requests.get(url + f'&start={page}')

    # Create a BeautifulSoup object from the response content
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find all the movie containers
    movie_containers = soup.find_all('div', class_='lister-item mode-advanced')

    # If no movie containers are found, exit the loop
    if not movie_containers:
        break

    # Iterate over each movie container
    for container in movie_containers:
        # Extract data for the first CSV
        title = container.h3.a.text.strip()
        directors = container.find('p', class_='').find_all('a')
        director_names = [director.text.strip() for director in directors]
        duration = container.find('span', class_='runtime').text.strip().split()[0]
        year = container.find('span', class_='lister-item-year').text.strip('()')
        rating = container.find('strong').text.strip()
        metascore = container.find('span', class_='metascore').text.strip() if container.find('span', class_='metascore') else ''

        first_csv_data.append({
            'Sno': len(first_csv_data) + 1,
            'Movie Name': title,
            'Director Name': ', '.join(director_names),
            'Duration': duration,
            'Year': year,
            'Ratings': rating,
            'Metascore': metascore
        })

        # Extract data for the second CSV
        stars = container.find('p', class_='').find_all('a')[1:]
        star_names = [star.text.strip() for star in stars]
        votes = container.find('span', attrs={'name': 'nv'})['data-value']
        genres = container.find('span', class_='genre').text.strip().split(', ')
        gross = container.find('p', class_='sort-num_votes-visible').find_all('span')[-1]['data-value'] if container.find('p', class_='sort-num_votes-visible').find_all('span') else ''
        popularity = container.find('div', class_='lister-item-content').find('div', class_='inline-block ratings-imdb-rating')['data-value']
        certification = container.find('span', class_='certificate').text.strip() if container.find('span', class_='certificate') else ''

        second_csv_data.append({
            'Movie Name': title,
            'Stars': ', '.join(star_names),
            'Votes': votes,
            'Genre': ', '.join(genres),
            'Gross collection': gross,
            'Popularity': popularity,
            'Certification': certification
        })

    page += 50

# %%
# Create a DataFrame for the first CSV data
first_csv_df = pd.DataFrame(first_csv_data)

# Create a DataFrame for the second CSV data
second_csv_df = pd.DataFrame(second_csv_data)

# %%
first_csv_df.head(5)
# Out:
#    Sno                                         Movie Name  \
# 0    1                Spider-Man: Across the Spider-Verse
# 1    2                                    The Dark Knight
# 2    3      The Lord of the Rings: The Return of the King
# 3    4                                          Inception
# 4    5  The Lord of the Rings: The Fellowship of the Ring
#
#                                        Director Name Duration  Year Ratings  \
# 0  Joaquim Dos Santos, Kemp Powers, Justin K. Tho...      140  2023     9.0
# 1  Christopher Nolan, Christian Bale, Heath Ledge...      152  2008     9.0
# 2  Peter Jackson, Elijah Wood, Viggo Mortensen, I...      201  2003     9.0
# 3  Christopher Nolan, Leonardo DiCaprio, Joseph G...      148  2010     8.8
# 4  Peter Jackson, Elijah Wood, Ian McKellen, Orla...      178  2001     8.8
#
#   Metascore
# 0        86
# 1        84
# 2        94
# 3        74
# 4        92

# %%
# Split the 'Stars' column into separate columns
split_directors = first_csv_df['Director Name'].str.split(', ', expand=True)

# Get the maximum number of stars in any row
max_directors = split_directors.apply(lambda row: len(row.dropna()), axis=1).max()

# Create new columns for stars
director_columns = [f'Director{i}' for i in range(1, max_directors + 1)]
first_csv_df[director_columns] = split_directors.iloc[:, :max_directors]

# %%
first_csv_df.head(5)
# Out:
#    Sno                                         Movie Name  \
# 0    1                Spider-Man: Across the Spider-Verse
# 1    2                                    The Dark Knight
# 2    3      The Lord of the Rings: The Return of the King
# 3    4                                          Inception
# 4    5  The Lord of the Rings: The Fellowship of the Ring
#
#                                        Director Name Duration  Year Ratings  \
# 0  Joaquim Dos Santos, Kemp Powers, Justin K. Tho...      140  2023     9.0
# 1  Christopher Nolan, Christian Bale, Heath Ledge...      152  2008     9.0
# 2  Peter Jackson, Elijah Wood, Viggo Mortensen, I...      201  2003     9.0
# 3  Christopher Nolan, Leonardo DiCaprio, Joseph G...      148  2010     8.8
# 4  Peter Jackson, Elijah Wood, Ian McKellen, Orla...      178  2001     8.8
#
#   Metascore           Director1          Director2             Director3  \
# 0        86  Joaquim Dos Santos        Kemp Powers    Justin K. Thompson
# 1        84   Christopher Nolan     Christian Bale          Heath Ledger
# 2        94       Peter Jackson        Elijah Wood       Viggo Mortensen
# 3        74   Christopher Nolan  Leonardo DiCaprio  Joseph Gordon-Levitt
# 4        92       Peter Jackson        Elijah Wood          Ian McKellen
#
#        Director4         Director5          Director6          Director7  \
# 0  Shameik Moore  Hailee Steinfeld  Brian Tyree Henry  Luna Lauren Velez
# 1  Aaron Eckhart     Michael Caine               None               None
# 2   Ian McKellen     Orlando Bloom               None               None
# 3    Elliot Page      Ken Watanabe               None               None
# 4  Orlando Bloom         Sean Bean               None               None
#
#   Director8 Director9 Director10
# 0      None      None       None
# 1      None      None       None
# 2      None      None       None
# 3      None      None       None
# 4      None      None       None

# %%
second_csv_df.head(5)
# Out:
#                                           Movie Name  \
# 0                Spider-Man: Across the Spider-Verse
# 1                                    The Dark Knight
# 2      The Lord of the Rings: The Return of the King
# 3                                          Inception
# 4  The Lord of the Rings: The Fellowship of the Ring
#
#                                                Stars    Votes  \
# 0  Kemp Powers, Justin K. Thompson, Shameik Moore...   127907
# 1  Christian Bale, Heath Ledger, Aaron Eckhart, M...  2725921
# 2  Elijah Wood, Viggo Mortensen, Ian McKellen, Or...  1891275
# 3  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...  2419368
# 4  Elijah Wood, Ian McKellen, Orlando Bloom, Sean...  1919868
#
#                           Genre Gross collection Popularity Certification
# 0  Animation, Action, Adventure           127907          9             U
# 1          Action, Crime, Drama      534,858,444          9            UA
# 2      Action, Adventure, Drama      377,845,905          9             U
# 3     Action, Adventure, Sci-Fi      292,576,195        8.8            UA
# 4      Action, Adventure, Drama      315,544,750        8.8             U

# %%
first_csv_df.drop("Director Name", axis=1, inplace=True)

# %%
first_csv_df.head(5)
# Out:
#    Sno                                         Movie Name Duration  Year  \
# 0    1                Spider-Man: Across the Spider-Verse      140  2023
# 1    2                                    The Dark Knight      152  2008
# 2    3      The Lord of the Rings: The Return of the King      201  2003
# 3    4                                          Inception      148  2010
# 4    5  The Lord of the Rings: The Fellowship of the Ring      178  2001
#
#   Ratings Metascore           Director1          Director2  \
# 0     9.0        86  Joaquim Dos Santos        Kemp Powers
# 1     9.0        84   Christopher Nolan     Christian Bale
# 2     9.0        94       Peter Jackson        Elijah Wood
# 3     8.8        74   Christopher Nolan  Leonardo DiCaprio
# 4     8.8        92       Peter Jackson        Elijah Wood
#
#               Director3      Director4         Director5          Director6  \
# 0    Justin K. Thompson  Shameik Moore  Hailee Steinfeld  Brian Tyree Henry
# 1          Heath Ledger  Aaron Eckhart     Michael Caine               None
# 2       Viggo Mortensen   Ian McKellen     Orlando Bloom               None
# 3  Joseph Gordon-Levitt    Elliot Page      Ken Watanabe               None
# 4          Ian McKellen  Orlando Bloom         Sean Bean               None
#
#            Director7 Director8 Director9 Director10
# 0  Luna Lauren Velez      None      None       None
# 1               None      None      None       None
# 2               None      None      None       None
# 3               None      None      None       None
# 4               None      None      None       None

# %%
first_csv_df.to_csv("directors_info.csv")

# %%
# Split the 'Stars' column into separate columns
split_stars = second_csv_df['Stars'].str.split(', ', expand=True)

# Get the maximum number of stars in any row
max_stars = split_stars.apply(lambda row: len(row.dropna()), axis=1).max()

# Create new columns for stars
star_columns = [f'Star{i}' for i in range(1, max_stars + 1)]
second_csv_df[star_columns] = split_stars.iloc[:, :max_stars]

# %%
second_csv_df.head(5)
# Out:
#                                           Movie Name  \
# 0                Spider-Man: Across the Spider-Verse
# 1                                    The Dark Knight
# 2      The Lord of the Rings: The Return of the King
# 3                                          Inception
# 4  The Lord of the Rings: The Fellowship of the Ring
#
#                                                Stars    Votes  \
# 0  Kemp Powers, Justin K. Thompson, Shameik Moore...   127907
# 1  Christian Bale, Heath Ledger, Aaron Eckhart, M...  2725921
# 2  Elijah Wood, Viggo Mortensen, Ian McKellen, Or...  1891275
# 3  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...  2419368
# 4  Elijah Wood, Ian McKellen, Orlando Bloom, Sean...  1919868
#
#                           Genre Gross collection Popularity Certification  \
# 0  Animation, Action, Adventure           127907          9             U
# 1          Action, Crime, Drama      534,858,444          9            UA
# 2      Action, Adventure, Drama      377,845,905          9             U
# 3     Action, Adventure, Sci-Fi      292,576,195        8.8            UA
# 4      Action, Adventure, Drama      315,544,750        8.8             U
#
#                Star1                 Star2          Star3             Star4  \
# 0        Kemp Powers    Justin K. Thompson  Shameik Moore  Hailee Steinfeld
# 1     Christian Bale          Heath Ledger  Aaron Eckhart     Michael Caine
# 2        Elijah Wood       Viggo Mortensen   Ian McKellen     Orlando Bloom
# 3  Leonardo DiCaprio  Joseph Gordon-Levitt    Elliot Page      Ken Watanabe
# 4        Elijah Wood          Ian McKellen  Orlando Bloom         Sean Bean
#
#                Star5              Star6 Star7 Star8 Star9
# 0  Brian Tyree Henry  Luna Lauren Velez  None  None  None
# 1               None               None  None  None  None
# 2               None               None  None  None  None
# 3               None               None  None  None  None
# 4               None               None  None  None  None

# %%
# Split the 'Genre' column into separate columns
split_genres = second_csv_df['Genre'].str.split(', ', expand=True)

# Get the maximum number of stars in any row
max_genres = split_genres.apply(lambda row: len(row.dropna()), axis=1).max()

# Create new columns for stars
genre_columns = [f'Genre{i}' for i in range(1, max_genres + 1)]
second_csv_df[genre_columns] = split_genres.iloc[:, :max_genres]

# %%
second_csv_df.head(5)
# Out:
#                                           Movie Name  \
# 0                Spider-Man: Across the Spider-Verse
# 1                                    The Dark Knight
# 2      The Lord of the Rings: The Return of the King
# 3                                          Inception
# 4  The Lord of the Rings: The Fellowship of the Ring
#
#                                                Stars    Votes  \
# 0  Kemp Powers, Justin K. Thompson, Shameik Moore...   127907
# 1  Christian Bale, Heath Ledger, Aaron Eckhart, M...  2725921
# 2  Elijah Wood, Viggo Mortensen, Ian McKellen, Or...  1891275
# 3  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...  2419368
# 4  Elijah Wood, Ian McKellen, Orlando Bloom, Sean...  1919868
#
#                           Genre Gross collection Popularity Certification  \
# 0  Animation, Action, Adventure           127907          9             U
# 1          Action, Crime, Drama      534,858,444          9            UA
# 2      Action, Adventure, Drama      377,845,905          9             U
# 3     Action, Adventure, Sci-Fi      292,576,195        8.8            UA
# 4      Action, Adventure, Drama      315,544,750        8.8             U
#
#                Star1                 Star2          Star3             Star4  \
# 0        Kemp Powers    Justin K. Thompson  Shameik Moore  Hailee Steinfeld
# 1     Christian Bale          Heath Ledger  Aaron Eckhart     Michael Caine
# 2        Elijah Wood       Viggo Mortensen   Ian McKellen     Orlando Bloom
# 3  Leonardo DiCaprio  Joseph Gordon-Levitt    Elliot Page      Ken Watanabe
# 4        Elijah Wood          Ian McKellen  Orlando Bloom         Sean Bean
#
#                Star5              Star6 Star7 Star8 Star9     Genre1  \
# 0  Brian Tyree Henry  Luna Lauren Velez  None  None  None  Animation
# 1               None               None  None  None  None     Action
# 2               None               None  None  None  None     Action
# 3               None               None  None  None  None     Action
# 4               None               None  None  None  None     Action
#
#       Genre2     Genre3
# 0     Action  Adventure
# 1      Crime      Drama
# 2  Adventure      Drama
# 3  Adventure     Sci-Fi
# 4  Adventure      Drama

# %%
second_csv_df.drop(["Stars", "Genre"], axis=1, inplace=True)

# %%
second_csv_df.head(5)
# Out:
#                                           Movie Name    Votes  \
# 0                Spider-Man: Across the Spider-Verse   127907
# 1                                    The Dark Knight  2725921
# 2      The Lord of the Rings: The Return of the King  1891275
# 3                                          Inception  2419368
# 4  The Lord of the Rings: The Fellowship of the Ring  1919868
#
#   Gross collection Popularity Certification              Star1  \
# 0           127907          9             U        Kemp Powers
# 1      534,858,444          9            UA     Christian Bale
# 2      377,845,905          9             U        Elijah Wood
# 3      292,576,195        8.8            UA  Leonardo DiCaprio
# 4      315,544,750        8.8             U        Elijah Wood
#
#                   Star2          Star3             Star4              Star5  \
# 0    Justin K. Thompson  Shameik Moore  Hailee Steinfeld  Brian Tyree Henry
# 1          Heath Ledger  Aaron Eckhart     Michael Caine               None
# 2       Viggo Mortensen   Ian McKellen     Orlando Bloom               None
# 3  Joseph Gordon-Levitt    Elliot Page      Ken Watanabe               None
# 4          Ian McKellen  Orlando Bloom         Sean Bean               None
#
#                Star6 Star7 Star8 Star9     Genre1     Genre2     Genre3
# 0  Luna Lauren Velez  None  None  None  Animation     Action  Adventure
# 1               None  None  None  None     Action      Crime      Drama
# 2               None  None  None  None     Action  Adventure      Drama
# 3               None  None  None  None     Action  Adventure     Sci-Fi
# 4               None  None  None  None     Action  Adventure      Drama

# %%
second_csv_df.to_csv("stars_info.csv")

# %% [markdown]
# ## Phase-2

# %% [markdown]
# ### Make two tables and corresponding columns provided in the above CSV files in SQLite DBMS. Insert all data of each CSV file in each of the created tables. Now start querying the table(s) in the  SQL workbench / SQLite database :
# #### Table 1: Sno, MovieName, Director Name, Duration, genre, ratings
# 1)  Display all the details of movies created by directors Christopher and Matt Reeves.
# 2) Display all the details of movies with a duration of 140 minutes to 190 minutes.
# 3) Display all details of movies with ratings above 7 in ascending order.
# 4) Display all movie names in descending order.
# 5) Display movie name starts with ‘P’ and their rating is greater than 7.
#
#
# #### Table 2: Movie Name, stars, votes, Genre, Gross collection, popularity, Certification
# 1) Display all movie names with star Arnold Schwarzenegger in ascending order.
# 2    2) Display all details of the movie with the highest number of votes.
# 3) Display movie names with gross collections in descending order.
# 4) Display the gross collection of movies with the star Arnold.
# 5) Display all details of movies with comedy and action genres.
#
# #### Make subquery :
# 1) Display all details from both tables where movie names are the same.
# 2)   Display all movie names, Director, ratings, and gross collection where the genre is action.
# 3)      Display all details from both tables with the highest gross collection.
# 4)      Display all details from both tables with the highest ratings
# 5)      Display all details from both tables with the lowest gross collection and lowest ratings
#
# #### Now once completed with queries in the SQLite database, then make the exact query solutions by using PANDAS SQL in the data frame.  Load the CSV data in a data frame and start making solutions for all the above 15 queries using PANDAS SQL. You may use concat or merge joins per the requirements basis to make 5 join queries.

# %%
# Import necessary Libraries
import sqlite3
from sqlite3 import Error
# Out:
# 2.6.0

# %%
# Create Sqllite database
def create_connection(db_file):
    """ create a database connection to a SQLite database """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        return conn
    except Error as e:
        print(e)

conn = create_connection(r"C:\Users\TCS\Desktop\Project\Capstone IMDB\imdb.db")
conn.close()

# %%
conn = create_connection(r"C:\Users\TCS\Desktop\Project\Capstone IMDB\imdb.db")
cur = conn.cursor()

# %%
# Create directors table

qry = """CREATE TABLE directors (
    Sno INTEGER,
    MovieName TEXT,
    Duration INTEGER,
    Year INTEGER,
    Ratings REAL,
    Metascore INTEGER,
    Director1 TEXT,
    Director2 TEXT,
    Director3 TEXT,
    Director4 TEXT,
    Director5 TEXT,
    Director6 TEXT,
    Director7 TEXT,
    Director8 TEXT,
    Director9 TEXT,
    Director10 TEXT
);
"""
cur.execute(qry)

# %%
directors_data = pd.read_csv("directors_info.csv", header=0)

# %%
directors_data.head(5)
# Out:
#    Sno                                         Movie Name  Duration  Year  \
# 0    1                Spider-Man: Across the Spider-Verse       140  2023
# 1    2                                    The Dark Knight       152  2008
# 2    3      The Lord of the Rings: The Return of the King       201  2003
# 3    4                                          Inception       148  2010
# 4    5  The Lord of the Rings: The Fellowship of the Ring       178  2001
#
#    Ratings  Metascore           Director1          Director2  \
# 0      9.0       86.0  Joaquim Dos Santos        Kemp Powers
# 1      9.0       84.0   Christopher Nolan     Christian Bale
# 2      9.0       94.0       Peter Jackson        Elijah Wood
# 3      8.8       74.0   Christopher Nolan  Leonardo DiCaprio
# 4      8.8       92.0       Peter Jackson        Elijah Wood
#
#               Director3      Director4         Director5          Director6  \
# 0    Justin K. Thompson  Shameik Moore  Hailee Steinfeld  Brian Tyree Henry
# 1          Heath Ledger  Aaron Eckhart     Michael Caine                NaN
# 2       Viggo Mortensen   Ian McKellen     Orlando Bloom                NaN
# 3  Joseph Gordon-Levitt    Elliot Page      Ken Watanabe                NaN
# 4          Ian McKellen  Orlando Bloom         Sean Bean                NaN
#
#            Director7 Director8 Director9 Director10
# 0  Luna Lauren Velez       NaN       NaN        NaN
# 1                NaN       NaN       NaN        NaN
# 2                NaN       NaN       NaN        NaN
# 3                NaN       NaN       NaN        NaN
# 4                NaN       NaN       NaN        NaN

# %%
# Insert directors data into table
directors_data.to_sql('directors', conn, if_exists='replace', index=False)
# Out:
# C:\Users\TCS\anaconda3 amita\lib\site-packages\pandas\core\generic.py:2872: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   sql.to_sql(

# %%
# Create stars table

qry = """CREATE TABLE stars (
    MovieName TEXT,
    Votes INTEGER,
    GrossCollection REAL,
    Popularity REAL,
    Certification TEXT,
    Star1 TEXT,
    Star2 TEXT,
    Star3 TEXT,
    Star4 TEXT,
    Star5 TEXT,
    Star6 TEXT,
    Star7 TEXT,
    Star8 TEXT,
    Star9 TEXT,
    Genre1 TEXT,
    Genre2 TEXT,
    Genre3 TEXT
);
"""
cur.execute(qry)

# %%
stars_data = pd.read_csv("stars_info.csv", header=0)

# %%
# Insert stars data into table
stars_data.to_sql('stars', conn, if_exists='replace', index=False)

# %%
#1)  Display all the details of movies created by directors Christopher and Matt Reeves
query = "SELECT * FROM directors WHERE Director1 IN ('Christopher Nolan', 'Matt Reeves') \
         OR Director2 IN ('Christopher Nolan', 'Matt Reeves') \
         OR Director3 IN ('Christopher Nolan', 'Matt Reeves') \
         OR Director4 IN ('Christopher Nolan', 'Matt Reeves') \
         OR Director5 IN ('Christopher Nolan', 'Matt Reeves') \
         OR Director6 IN ('Christopher Nolan', 'Matt Reeves') \
         OR Director7 IN ('Christopher Nolan', 'Matt Reeves') \
         OR Director8 IN ('Christopher Nolan', 'Matt Reeves') \
         OR Director9 IN ('Christopher Nolan', 'Matt Reeves');"
df = pd.read_sql_query(query, conn)
df
# Out:
#    Sno                      Movie Name  Duration  Year  Ratings  Metascore  \
# 0    2                 The Dark Knight       152  2008      9.0       84.0
# 1    4                       Inception       148  2010      8.8       74.0
# 2   22           The Dark Knight Rises       164  2012      8.4       78.0
# 3   42                   Batman Begins       140  2005      8.2       70.0
# 4  131                      The Batman       176  2022      7.8       72.0
# 5  137                         Dunkirk       106  2017      7.8       94.0
# 6  225  Dawn of the Planet of the Apes       130  2014      7.6       79.0
# 7  305  War for the Planet of the Apes       140  2017      7.4       82.0
# 8  322                           Tenet       150  2020      7.3       69.0
# 9  502                     Cloverfield        85  2008      7.0       64.0
#
#            Director1              Director2             Director3  \
# 0  Christopher Nolan         Christian Bale          Heath Ledger
# 1  Christopher Nolan      Leonardo DiCaprio  Joseph Gordon-Levitt
# 2  Christopher Nolan         Christian Bale             Tom Hardy
# 3  Christopher Nolan         Christian Bale         Michael Caine
# 4        Matt Reeves       Robert Pattinson           Zoë Kravitz
# 5  Christopher Nolan        Fionn Whitehead         Barry Keoghan
# 6        Matt Reeves            Gary Oldman          Keri Russell
# 7        Matt Reeves            Andy Serkis       Woody Harrelson
# 8  Christopher Nolan  John David Washington      Robert Pattinson
# 9        Matt Reeves             Mike Vogel         Jessica Lucas
#
#            Director4         Director5 Director6 Director7 Director8  \
# 0      Aaron Eckhart     Michael Caine      None      None      None
# 1        Elliot Page      Ken Watanabe      None      None      None
# 2      Anne Hathaway       Gary Oldman      None      None      None
# 3       Ken Watanabe       Liam Neeson      None      None      None
# 4     Jeffrey Wright     Colin Farrell      None      None      None
# 5       Mark Rylance         Tom Hardy      None      None      None
# 6        Andy Serkis  Kodi Smit-McPhee      None      None      None
# 7         Steve Zahn     Karin Konoval      None      None      None
# 8  Elizabeth Debicki      Juhan Ulfsak      None      None      None
# 9       Lizzy Caplan       T.J. Miller      None      None      None
#
#   Director9 Director10
# 0      None       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5      None       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None

# %%
#2) Display all the details of movies with a duration of 140 minutes to 190 minutes.
query = "SELECT * FROM directors WHERE Duration >= 140 and Duration <= 190;"
df = pd.read_sql_query(query, conn)
df
# Out:
#       Sno                                         Movie Name  Duration  Year  \
# 0       1                Spider-Man: Across the Spider-Verse       140  2023
# 1       2                                    The Dark Knight       152  2008
# 2       4                                          Inception       148  2010
# 3       5  The Lord of the Rings: The Fellowship of the Ring       178  2001
# 4       6              The Lord of the Rings: The Two Towers       179  2002
# ..    ...                                                ...       ...   ...
# 199  1740                                             Gunday       152  2014
# 200  1741                                              Liger       140  2022
# 201  1744                                        Heropanti 2       145  2022
# 202  1745                                             Laxmii       141  2020
# 203  1750                                             Race 3       160  2018
#
#      Ratings  Metascore           Director1            Director2  \
# 0        9.0       86.0  Joaquim Dos Santos          Kemp Powers
# 1        9.0       84.0   Christopher Nolan       Christian Bale
# 2        8.8       74.0   Christopher Nolan    Leonardo DiCaprio
# 3        8.8       92.0       Peter Jackson          Elijah Wood
# 4        8.8       87.0       Peter Jackson          Elijah Wood
# ..       ...        ...                 ...                  ...
# 199      2.7        NaN     Ali Abbas Zafar        Ranveer Singh
# 200      2.7        NaN      Puri Jagannadh           Mike Tyson
# 201      2.5        NaN          Ahmed Khan         Tiger Shroff
# 202      2.5        NaN    Raghava Lawrence  Balakrishnan Thevar
# 203      1.9        NaN        Remo D'Souza          Anil Kapoor
#
#                 Director3              Director4             Director5  \
# 0      Justin K. Thompson          Shameik Moore      Hailee Steinfeld
# 1            Heath Ledger          Aaron Eckhart         Michael Caine
# 2    Joseph Gordon-Levitt            Elliot Page          Ken Watanabe
# 3            Ian McKellen          Orlando Bloom             Sean Bean
# 4            Ian McKellen        Viggo Mortensen         Orlando Bloom
# ..                    ...                    ...                   ...
# 199          Arjun Kapoor  Priyanka Chopra Jonas           Irrfan Khan
# 200     Vijay Deverakonda          Ananya Panday        Ramya Krishnan
# 201   Nawazuddin Siddiqui           Tara Sutaria     Amber Doig-Thorne
# 202          Akshay Kumar           Kiara Advani         Sharad Kelkar
# 203           Salman Khan             Bobby Deol  Jacqueline Fernandez
#
#              Director6          Director7 Director8 Director9 Director10
# 0    Brian Tyree Henry  Luna Lauren Velez      None      None       None
# 1                 None               None      None      None       None
# 2                 None               None      None      None       None
# 3                 None               None      None      None       None
# 4                 None               None      None      None       None
# ..                 ...                ...       ...       ...        ...
# 199               None               None      None      None       None
# 200               None               None      None      None       None
# 201               None               None      None      None       None
# 202   Ashwini Kalsekar               None      None      None       None
# 203               None               None      None      None       None
#
# [204 rows x 16 columns]

# %%
#3) Display all the details of movies with ratings above 7 in ascending order.
query = "SELECT * FROM directors WHERE Ratings > 7 ORDER BY Ratings ASC;"
df = pd.read_sql_query(query, conn)
df
# Out:
#      Sno                                         Movie Name  Duration  Year  \
# 0    430                                   Fast & Furious 7       137  2015
# 1    431                                          The Mummy       124  1999
# 2    432                                       Wrath of Man       119  2021
# 3    433                                Mission: Impossible       110  1996
# 4    434                                           Free Guy       115  2021
# ..   ...                                                ...       ...   ...
# 483    5  The Lord of the Rings: The Fellowship of the Ring       178  2001
# 484    6              The Lord of the Rings: The Two Towers       179  2002
# 485    1                Spider-Man: Across the Spider-Verse       140  2023
# 486    2                                    The Dark Knight       152  2008
# 487    3      The Lord of the Rings: The Return of the King       201  2003
#
#      Ratings  Metascore           Director1       Director2  \
# 0        7.1       67.0           James Wan      Vin Diesel
# 1        7.1       48.0     Stephen Sommers  Brendan Fraser
# 2        7.1       57.0         Guy Ritchie   Jason Statham
# 3        7.1       59.0      Brian De Palma      Tom Cruise
# 4        7.1       62.0          Shawn Levy   Ryan Reynolds
# ..       ...        ...                 ...             ...
# 483      8.8       92.0       Peter Jackson     Elijah Wood
# 484      8.8       87.0       Peter Jackson     Elijah Wood
# 485      9.0       86.0  Joaquim Dos Santos     Kemp Powers
# 486      9.0       84.0   Christopher Nolan  Christian Bale
# 487      9.0       94.0       Peter Jackson     Elijah Wood
#
#               Director3         Director4           Director5  \
# 0           Paul Walker    Dwayne Johnson       Jason Statham
# 1          Rachel Weisz       John Hannah       Arnold Vosloo
# 2        Holt McCallany     Josh Hartnett  Rocci Boy Williams
# 3            Jon Voight  Emmanuelle Béart        Henry Czerny
# 4           Jodie Comer     Taika Waititi      Lil Rel Howery
# ..                  ...               ...                 ...
# 483        Ian McKellen     Orlando Bloom           Sean Bean
# 484        Ian McKellen   Viggo Mortensen       Orlando Bloom
# 485  Justin K. Thompson     Shameik Moore    Hailee Steinfeld
# 486        Heath Ledger     Aaron Eckhart       Michael Caine
# 487     Viggo Mortensen      Ian McKellen       Orlando Bloom
#
#              Director6          Director7 Director8 Director9 Director10
# 0                 None               None      None      None       None
# 1                 None               None      None      None       None
# 2                 None               None      None      None       None
# 3                 None               None      None      None       None
# 4                 None               None      None      None       None
# ..                 ...                ...       ...       ...        ...
# 483               None               None      None      None       None
# 484               None               None      None      None       None
# 485  Brian Tyree Henry  Luna Lauren Velez      None      None       None
# 486               None               None      None      None       None
# 487               None               None      None      None       None
#
# [488 rows x 16 columns]

# %%
#4) Display all movie names in descending order.
query = "SELECT * FROM directors ORDER BY 'Movie Name' DESC;"
df = pd.read_sql_query(query, conn)
df
# Out:
#        Sno                                         Movie Name  Duration  Year  \
# 0        1                Spider-Man: Across the Spider-Verse       140  2023
# 1        2                                    The Dark Knight       152  2008
# 2        3      The Lord of the Rings: The Return of the King       201  2003
# 3        4                                          Inception       148  2010
# 4        5  The Lord of the Rings: The Fellowship of the Ring       178  2001
# ...    ...                                                ...       ...   ...
# 1748  1749                                              Radhe       109  2021
# 1749  1750                                             Race 3       160  2018
# 1750  1751                                  Angels Apocalypse        85  2015
# 1751  1752                                           Elk*rtuk       125  2021
# 1752  1753                                            Sadak 2       133  2020
#
#       Ratings  Metascore           Director1          Director2  \
# 0         9.0       86.0  Joaquim Dos Santos        Kemp Powers
# 1         9.0       84.0   Christopher Nolan     Christian Bale
# 2         9.0       94.0       Peter Jackson        Elijah Wood
# 3         8.8       74.0   Christopher Nolan  Leonardo DiCaprio
# 4         8.8       92.0       Peter Jackson        Elijah Wood
# ...       ...        ...                 ...                ...
# 1748      1.9        NaN         Prabhu Deva        Salman Khan
# 1749      1.9        NaN        Remo D'Souza        Anil Kapoor
# 1750      1.6        NaN           Sean Cain      Enzo Zelocchi
# 1751      1.5        NaN       Keith English  Vivianne Bánovits
# 1752      1.2        NaN        Mahesh Bhatt         Alia Bhatt
#
#                  Director3      Director4             Director5  \
# 0       Justin K. Thompson  Shameik Moore      Hailee Steinfeld
# 1             Heath Ledger  Aaron Eckhart         Michael Caine
# 2          Viggo Mortensen   Ian McKellen         Orlando Bloom
# 3     Joseph Gordon-Levitt    Elliot Page          Ken Watanabe
# 4             Ian McKellen  Orlando Bloom             Sean Bean
# ...                    ...            ...                   ...
# 1748          Disha Patani  Randeep Hooda         Jackie Shroff
# 1749           Salman Khan     Bobby Deol  Jacqueline Fernandez
# 1750         Enzo Zelocchi  Jana Rochelle     Ryan C.F. Buckley
# 1751          András Mózes    Barna Bokor       Gabriella Gubás
# 1752         Priyanka Bose    Sanjay Dutt     Aditya Roy Kapoor
#
#               Director6          Director7 Director8 Director9 Director10
# 0     Brian Tyree Henry  Luna Lauren Velez      None      None       None
# 1                  None               None      None      None       None
# 2                  None               None      None      None       None
# 3                  None               None      None      None       None
# 4                  None               None      None      None       None
# ...                 ...                ...       ...       ...        ...
# 1748               None               None      None      None       None
# 1749               None               None      None      None       None
# 1750    William Kirkham               None      None      None       None
# 1751               None               None      None      None       None
# 1752               None               None      None      None       None
#
# [1753 rows x 16 columns]

# %%
#5) Display movie name starts with ‘P’ and their rating is greater than 7.
query = "SELECT * FROM directors WHERE `Movie Name` LIKE 'P%' AND Ratings > 7;"
df = pd.read_sql_query(query, conn)
df
# Out:
#     Sno                                         Movie Name  Duration  \
# 0    57                                   Paan Singh Tomar       135
# 1    59  Pirates of the Caribbean: The Curse of the Bla...       143
# 2   119                            Per un pugno di dollari        99
# 3   142                                           Predator       107
# 4   192                                 Ponniyin Selvan: I       167
# 5   238                          Pushpa: The Rise - Part 1       179
# 6   293                                     Predestination        97
# 7   339         Pirates of the Caribbean: Dead Man's Chest       151
# 8   343                                       Patriots Day       133
# 9   380                                        Point Break       122
# 10  438                                               Prey       100
# 11  442           Pirates of the Caribbean: At World's End       169
# 12  459                                      Planet Terror       105
# 13  470                                            Payback       100
#
#         Year  Ratings  Metascore         Director1              Director2  \
# 0       2012      8.2        NaN  Tigmanshu Dhulia            Irrfan Khan
# 1       2003      8.1       63.0    Gore Verbinski            Johnny Depp
# 2       1964      7.9       65.0      Sergio Leone         Clint Eastwood
# 3       1987      7.8       47.0    John McTiernan  Arnold Schwarzenegger
# 4       2022      7.7        NaN       Mani Ratnam                 Vikram
# 5       2021      7.6        NaN           Sukumar             Allu Arjun
# 6   I) (2014      7.4       69.0   Michael Spierig          Peter Spierig
# 7       2006      7.3       53.0    Gore Verbinski            Johnny Depp
# 8       2016      7.3       69.0        Peter Berg          Mark Wahlberg
# 9       1991      7.2       59.0   Kathryn Bigelow         Patrick Swayze
# 10  I) (2022      7.1       71.0  Dan Trachtenberg       Amber Midthunder
# 11      2007      7.1       50.0    Gore Verbinski            Johnny Depp
# 12      2007      7.1        NaN  Robert Rodriguez           Rose McGowan
# 13  I) (1999      7.1       46.0   Brian Helgeland             Mel Gibson
#
#                  Director3          Director4                  Director5  \
# 0               Mahie Gill       Rajesh Abhay         Hemendra Dandotiya
# 1            Geoffrey Rush      Orlando Bloom            Keira Knightley
# 2       Gian Maria Volontè      Marianne Koch           Wolfgang Lukschy
# 3            Carl Weathers   Kevin Peter Hall           Elpidia Carrillo
# 4   Aishwarya Rai Bachchan         Jayam Ravi                     Karthi
# 5            Fahadh Faasil  Rashmika Mandanna  Jagadeesh Prathap Bandari
# 6              Ethan Hawke        Sarah Snook                Noah Taylor
# 7            Orlando Bloom    Keira Knightley             Jack Davenport
# 8        Michelle Monaghan       J.K. Simmons               John Goodman
# 9             Keanu Reeves         Gary Busey                 Lori Petty
# 10          Dakota Beavers      Dane DiLiegro               Stormee Kipp
# 11           Orlando Bloom    Keira Knightley              Geoffrey Rush
# 12        Freddy Rodríguez        Josh Brolin             Marley Shelton
# 13             Gregg Henry        Maria Bello               David Paymer
#
#          Director6 Director7 Director8 Director9 Director10
# 0             None      None      None      None       None
# 1             None      None      None      None       None
# 2             None      None      None      None       None
# 3             None      None      None      None       None
# 4             None      None      None      None       None
# 5             None      None      None      None       None
# 6   Madeleine West      None      None      None       None
# 7             None      None      None      None       None
# 8             None      None      None      None       None
# 9             None      None      None      None       None
# 10            None      None      None      None       None
# 11            None      None      None      None       None
# 12            None      None      None      None       None
# 13            None      None      None      None       None

# %%
#1)  Display all movie names with star Arnold Schwarzenegger in ascending order
query = "SELECT * FROM stars WHERE star1 IN ('Arnold Schwarzenegger') \
         OR star2 IN ('Arnold Schwarzenegger') \
         OR star3 IN ('Arnold Schwarzenegger') \
         OR star4 IN ('Arnold Schwarzenegger') \
         OR star5 IN ('Arnold Schwarzenegger') \
         OR star6 IN ('Arnold Schwarzenegger') \
         OR star7 IN ('Arnold Schwarzenegger') \
         OR star8 IN ('Arnold Schwarzenegger') \
         OR star9 IN ('Arnold Schwarzenegger') ORDER BY 'Ratings' ASC;"
df = pd.read_sql_query(query, conn)
df
# Out:
#                             Movie Name    Votes Gross collection  Popularity  \
# 0           Terminator 2: Judgment Day  1124566      204,843,350         8.6
# 1                       The Terminator   886572       38,400,000         8.1
# 2                             Predator   435013       59,735,548         7.8
# 3                         Total Recall   341210      119,394,840         7.5
# 4                            True Lies   269561      146,282,411         7.3
# 5                  Conan the Barbarian   155773       39,565,475         6.9
# 6                             Commando   167620       35,100,000         6.7
# 7                          Escape Plan   249927       25,132,228         6.7
# 8                      The Running Man   159185       38,122,105         6.6
# 9                     Last Action Hero   157517       50,016,394         6.4
# 10                  Terminator Genisys   284740       89,760,956         6.3
# 11                      The Last Stand   142496       12,050,299         6.3
# 12  Terminator 3: Rise of the Machines   408078      150,371,112         6.3
# 13                    Kindergarten Cop   156023       91,457,688         6.2
# 14               Terminator: Dark Fate   184801       62,253,077         6.2
# 15                              Eraser   115028      101,295,562         6.2
# 16                            Red Heat    73422       34,994,648         6.1
# 17                 Conan the Destroyer    82881       31,042,035         5.9
# 18                         The 6th Day   125182       34,604,280         5.9
# 19                         End of Days   113549       66,889,043         5.8
# 20                            Sabotage    64912       10,508,518         5.7
# 21                            Raw Deal    35982       16,209,459         5.6
# 22                   Collateral Damage    76545       40,077,257         5.5
# 23                           Red Sonja    43408        6,948,633         5.1
# 24                      Batman & Robin   259892      107,325,195         3.7
#
#    Certification                  Star1                  Star2  \
# 0              A  Arnold Schwarzenegger         Linda Hamilton
# 1              A  Arnold Schwarzenegger         Linda Hamilton
# 2              A  Arnold Schwarzenegger          Carl Weathers
# 3              A  Arnold Schwarzenegger           Sharon Stone
# 4              A  Arnold Schwarzenegger       Jamie Lee Curtis
# 5              A  Arnold Schwarzenegger       James Earl Jones
# 6              A  Arnold Schwarzenegger         Rae Dawn Chong
# 7              A     Sylvester Stallone  Arnold Schwarzenegger
# 8              A  Arnold Schwarzenegger  Maria Conchita Alonso
# 9              U  Arnold Schwarzenegger      F. Murray Abraham
# 10            UA  Arnold Schwarzenegger           Jason Clarke
# 11             A  Arnold Schwarzenegger        Forest Whitaker
# 12            UA  Arnold Schwarzenegger             Nick Stahl
# 13             U  Arnold Schwarzenegger    Penelope Ann Miller
# 14            UA         Linda Hamilton  Arnold Schwarzenegger
# 15             A  Arnold Schwarzenegger       Vanessa Williams
# 16             A  Arnold Schwarzenegger            Jim Belushi
# 17            UA  Arnold Schwarzenegger            Grace Jones
# 18             U  Arnold Schwarzenegger       Michael Rapaport
# 19             R  Arnold Schwarzenegger          Gabriel Byrne
# 20             A  Arnold Schwarzenegger        Sam Worthington
# 21             A  Arnold Schwarzenegger        Kathryn Harrold
# 22             A  Arnold Schwarzenegger         John Leguizamo
# 23             U  Arnold Schwarzenegger       Brigitte Nielsen
# 24             U  Arnold Schwarzenegger         George Clooney
#
#                Star3              Star4 Star5 Star6 Star7 Star8 Star9  Genre1  \
# 0     Edward Furlong     Robert Patrick  None  None  None  None  None  Action
# 1      Michael Biehn      Paul Winfield  None  None  None  None  None  Action
# 2   Kevin Peter Hall   Elpidia Carrillo  None  None  None  None  None  Action
# 3   Michael Ironside     Rachel Ticotin  None  None  None  None  None  Action
# 4         Tom Arnold        Bill Paxton  None  None  None  None  None  Action
# 5      Max von Sydow    Sandahl Bergman  None  None  None  None  None  Action
# 6         Dan Hedaya       Vernon Wells  None  None  None  None  None  Action
# 7            50 Cent  Vincent D'Onofrio  None  None  None  None  None  Action
# 8       Yaphet Kotto          Jim Brown  None  None  None  None  None  Action
# 9         Art Carney      Charles Dance  None  None  None  None  None  Action
# 10     Emilia Clarke       Jai Courtney  None  None  None  None  None  Action
# 11  Johnny Knoxville    Rodrigo Santoro  None  None  None  None  None  Action
# 12   Kristanna Loken       Claire Danes  None  None  None  None  None  Action
# 13       Pamela Reed         Linda Hunt  None  None  None  None  None  Action
# 14   Mackenzie Davis      Natalia Reyes  None  None  None  None  None  Action
# 15        James Caan       James Coburn  None  None  None  None  None  Action
# 16       Peter Boyle          Ed O'Ross  None  None  None  None  None  Action
# 17      Olivia d'Abo   Wilt Chamberlain  None  None  None  None  None  Action
# 18      Tony Goldwyn     Michael Rooker  None  None  None  None  None  Action
# 19      Robin Tunney       Kevin Pollak  None  None  None  None  None  Action
# 20   Terrence Howard    Olivia Williams  None  None  None  None  None  Action
# 21     Sam Wanamaker        Paul Shenar  None  None  None  None  None  Action
# 22    Francesca Neri       Elias Koteas  None  None  None  None  None  Action
# 23   Sandahl Bergman      Paul L. Smith  None  None  None  None  None  Action
# 24   Chris O'Donnell        Uma Thurman  None  None  None  None  None  Action
#
#        Genre2    Genre3
# 0      Sci-Fi      None
# 1      Sci-Fi      None
# 2   Adventure    Horror
# 3   Adventure    Sci-Fi
# 4      Comedy  Thriller
# 5   Adventure   Fantasy
# 6   Adventure  Thriller
# 7    Thriller      None
# 8      Sci-Fi  Thriller
# 9   Adventure    Comedy
# 10  Adventure    Sci-Fi
# 11   Thriller   Western
# 12     Sci-Fi      None
# 13     Comedy     Crime
# 14  Adventure    Sci-Fi
# 15      Crime  Thriller
# 16     Comedy     Crime
# 17  Adventure   Fantasy
# 18    Mystery    Sci-Fi
# 19    Fantasy    Horror
# 20      Crime     Drama
# 21      Crime  Thriller
# 22      Drama  Thriller
# 23  Adventure   Fantasy
# 24     Sci-Fi      None

# %%
#2) Display all details of the movie with the highest number of votes.
query = "SELECT * FROM stars ORDER BY Votes DESC LIMIT 1;"
df = pd.read_sql_query(query, conn)
df
# Out:
#         Movie Name    Votes Gross collection  Popularity Certification  \
# 0  The Dark Knight  2722695      534,858,444         9.0            UA
#
#             Star1         Star2          Star3          Star4 Star5 Star6  \
# 0  Christian Bale  Heath Ledger  Aaron Eckhart  Michael Caine  None  None
#
#   Star7 Star8 Star9  Genre1 Genre2 Genre3
# 0  None  None  None  Action  Crime  Drama

# %%
#3) Display movie names with gross collections in descending order
query = "SELECT * FROM stars ORDER BY `Gross collection` DESC;"
df = pd.read_sql_query(query, conn)
df
# Out:
#                            Movie Name   Votes Gross collection  Popularity  \
# 0           Hitman's Wife's Bodyguard   99869            99869         6.1
# 1                  Gangs of Wasseypur   99452            99452         8.2
# 2                  Olympus Has Fallen  283770       98,925,640         6.5
# 3                    The Green Hornet  162608       98,780,042         5.8
# 4                        Sherlock Jr.   52562          977,375         8.2
# ...                               ...     ...              ...         ...
# 1748                Love and Monsters  134625        1,070,714         6.9
# 1749                      The General   93990        1,033,895         8.1
# 1750                 Attack the Block  109055        1,024,175         6.7
# 1751  Cowboy Bebop: Tengoku no tobira   50720        1,000,045         7.8
# 1752                 Army of the Dead  178640        1,000,000         5.8
#
#      Certification           Star1                Star2              Star3  \
# 0                A   Ryan Reynolds    Samuel L. Jackson        Salma Hayek
# 1                A  Manoj Bajpayee  Nawazuddin Siddiqui   Tigmanshu Dhulia
# 2                A   Gerard Butler        Aaron Eckhart     Morgan Freeman
# 3               18      Seth Rogen             Jay Chou    Christoph Waltz
# 4             None   Buster Keaton      Kathryn McGuire         Joe Keaton
# ...            ...             ...                  ...                ...
# 1748            13   Dylan O'Brien      Jessica Henwick     Michael Rooker
# 1749          None   Buster Keaton        Buster Keaton        Marion Mack
# 1750             R     John Boyega      Jodie Whittaker        Alex Esmail
# 1751             U  Tensai Okamura      Hiroyuki Okiura    Yoshiyuki Takei
# 1752            18   Dave Bautista         Ella Purnell  Ana de la Reguera
#
#                  Star4         Star5           Star6            Star7 Star8  \
# 0     Antonio Banderas          None            None             None  None
# 1         Richa Chadha          None            None             None  None
# 2       Angela Bassett          None            None             None  None
# 3         Cameron Diaz          None            None             None  None
# 4       Erwin Connelly          None            None             None  None
# ...                ...           ...             ...              ...   ...
# 1748         Dan Ewing          None            None             None  None
# 1749     Glen Cavender    Jim Farley            None             None  None
# 1750       Leeon Jones          None            None             None  None
# 1751  Beau Billingslea  Melissa Fahn  Nicholas Guest  Kôichi Yamadera  None
# 1752    Omari Hardwick          None            None             None  None
#
#      Star9     Genre1     Genre2   Genre3
# 0     None     Action     Comedy    Crime
# 1     None     Action     Comedy    Crime
# 2     None     Action   Thriller     None
# 3     None     Action     Comedy    Crime
# 4     None     Action     Comedy  Romance
# ...    ...        ...        ...      ...
# 1748  None     Action  Adventure   Comedy
# 1749  None     Action  Adventure   Comedy
# 1750  None     Action  Adventure   Comedy
# 1751  None  Animation     Action    Crime
# 1752  None     Action      Crime    Drama
#
# [1753 rows x 17 columns]

# %%
#4) Display the gross collection of movies with the star Arnold.
 
query = "SELECT `Gross collection` FROM stars WHERE star1 LIKE '%Arnold%' OR star2 LIKE '%Arnold%' OR star3 LIKE '%Arnold%'"
df = pd.read_sql_query(query, conn)
df
# Out:
#    Gross collection
# 0       204,843,350
# 1        38,400,000
# 2        59,735,548
# 3       119,394,840
# 4       146,282,411
# 5        39,565,475
# 6        35,100,000
# 7        25,132,228
# 8        38,122,105
# 9        50,016,394
# 10       89,760,956
# 11       12,050,299
# 12      150,371,112
# 13       91,457,688
# 14       62,253,077
# 15      101,295,562
# 16       34,994,648
# 17       31,042,035
# 18       34,604,280
# 19       66,889,043
# 20       10,508,518
# 21       16,209,459
# 22       40,077,257
# 23        6,948,633
# 24      107,325,195

# %%
#5) Display all details of movies with comedy and action genres.

query = "SELECT * FROM stars WHERE Genre1 = 'Comedy' OR Genre2 = 'Comedy' OR Genre3 = 'Comedy' AND (Genre1 = 'Action' OR Genre2 = 'Action' OR Genre3 = 'Action')"
df = pd.read_sql_query(query, conn)
df
# Out:
#                                       Movie Name   Votes Gross collection  \
# 0                 Guardians of the Galaxy Vol. 3  164600           164600
# 1                             Gangs of Wasseypur   99452            99452
# 2                                   Sherlock Jr.   52562          977,375
# 3            Lock, Stock and Two Smoking Barrels  595814        3,897,569
# 4                                    The General   93990        1,033,895
# ..                                           ...     ...              ...
# 366                 The Adventures of Pluto Nash   26472        4,420,080
# 367  The Adventures of Sharkboy and Lavagirl 3-D   40053       39,177,684
# 368        Spy Kids 4: All the Time in the World   27006       38,538,188
# 369                                  Heropanti 2   26997            26997
# 370                                       Laxmii   57994            57994
#
#      Popularity Certification                Star1                Star2  \
# 0           8.2            UA          Chris Pratt       Chukwudi Iwuji
# 1           8.2             A       Manoj Bajpayee  Nawazuddin Siddiqui
# 2           8.2          None        Buster Keaton      Kathryn McGuire
# 3           8.1             A        Jason Flemyng      Dexter Fletcher
# 4           8.1          None        Buster Keaton        Buster Keaton
# ..          ...           ...                  ...                  ...
# 366         3.8         PG-13         Eddie Murphy             Jay Mohr
# 367         3.7             U          Cayden Boyd         George Lopez
# 368         3.5            PG         Jessica Alba         Jeremy Piven
# 369         2.5            UA         Tiger Shroff  Nawazuddin Siddiqui
# 370         2.5        UA 16+  Balakrishnan Thevar         Akshay Kumar
#
#                 Star3              Star4             Star5 Star6 Star7 Star8  \
# 0      Bradley Cooper    Pom Klementieff              None  None  None  None
# 1    Tigmanshu Dhulia       Richa Chadha              None  None  None  None
# 2          Joe Keaton     Erwin Connelly              None  None  None  None
# 3          Nick Moran      Jason Statham              None  None  None  None
# 4         Marion Mack      Glen Cavender        Jim Farley  None  None  None
# ..                ...                ...               ...   ...   ...   ...
# 366       Randy Quaid     Rosario Dawson              None  None  None  None
# 367     Kristin Davis     David Arquette              None  None  None  None
# 368       Joel McHale    Rowan Blanchard              None  None  None  None
# 369      Tara Sutaria  Amber Doig-Thorne              None  None  None  None
# 370      Kiara Advani      Sharad Kelkar  Ashwini Kalsekar  None  None  None
#
#     Star9  Genre1     Genre2   Genre3
# 0    None  Action  Adventure   Comedy
# 1    None  Action     Comedy    Crime
# 2    None  Action     Comedy  Romance
# 3    None  Action     Comedy    Crime
# 4    None  Action  Adventure   Comedy
# ..    ...     ...        ...      ...
# 366  None  Action     Comedy   Sci-Fi
# 367  None  Action  Adventure   Comedy
# 368  None  Action  Adventure   Comedy
# 369  None  Action     Comedy    Crime
# 370  None  Action     Comedy   Horror
#
# [371 rows x 17 columns]

# %% [markdown]
# ### Make subquery :

# %%
#1) Display all details from both tables where movie names are the same.

query = """
SELECT *
FROM directors
INNER JOIN stars ON directors.`Movie Name` = stars.`Movie Name`
"""
df = pd.read_sql_query(query, conn)
df
# Out:
#        Sno                                         Movie Name  Duration  Year  \
# 0        1                Spider-Man: Across the Spider-Verse       140  2023
# 1        2                                    The Dark Knight       152  2008
# 2        3      The Lord of the Rings: The Return of the King       201  2003
# 3        4                                          Inception       148  2010
# 4        5  The Lord of the Rings: The Fellowship of the Ring       178  2001
# ...    ...                                                ...       ...   ...
# 1810  1749                                              Radhe       109  2021
# 1811  1750                                             Race 3       160  2018
# 1812  1751                                  Angels Apocalypse        85  2015
# 1813  1752                                           Elk*rtuk       125  2021
# 1814  1753                                            Sadak 2       133  2020
#
#       Ratings  Metascore           Director1          Director2  \
# 0         9.0       86.0  Joaquim Dos Santos        Kemp Powers
# 1         9.0       84.0   Christopher Nolan     Christian Bale
# 2         9.0       94.0       Peter Jackson        Elijah Wood
# 3         8.8       74.0   Christopher Nolan  Leonardo DiCaprio
# 4         8.8       92.0       Peter Jackson        Elijah Wood
# ...       ...        ...                 ...                ...
# 1810      1.9        NaN         Prabhu Deva        Salman Khan
# 1811      1.9        NaN        Remo D'Souza        Anil Kapoor
# 1812      1.6        NaN           Sean Cain      Enzo Zelocchi
# 1813      1.5        NaN       Keith English  Vivianne Bánovits
# 1814      1.2        NaN        Mahesh Bhatt         Alia Bhatt
#
#                  Director3      Director4  ...          Star3  \
# 0       Justin K. Thompson  Shameik Moore  ...  Shameik Moore
# 1             Heath Ledger  Aaron Eckhart  ...  Aaron Eckhart
# 2          Viggo Mortensen   Ian McKellen  ...   Ian McKellen
# 3     Joseph Gordon-Levitt    Elliot Page  ...    Elliot Page
# 4             Ian McKellen  Orlando Bloom  ...  Orlando Bloom
# ...                    ...            ...  ...            ...
# 1810          Disha Patani  Randeep Hooda  ...  Randeep Hooda
# 1811           Salman Khan     Bobby Deol  ...     Bobby Deol
# 1812         Enzo Zelocchi  Jana Rochelle  ...  Jana Rochelle
# 1813          András Mózes    Barna Bokor  ...    Barna Bokor
# 1814         Priyanka Bose    Sanjay Dutt  ...    Sanjay Dutt
#
#                      Star4              Star5              Star6 Star7 Star8  \
# 0         Hailee Steinfeld  Brian Tyree Henry  Luna Lauren Velez  None  None
# 1            Michael Caine               None               None  None  None
# 2            Orlando Bloom               None               None  None  None
# 3             Ken Watanabe               None               None  None  None
# 4                Sean Bean               None               None  None  None
# ...                    ...                ...                ...   ...   ...
# 1810         Jackie Shroff               None               None  None  None
# 1811  Jacqueline Fernandez               None               None  None  None
# 1812     Ryan C.F. Buckley    William Kirkham               None  None  None
# 1813       Gabriella Gubás               None               None  None  None
# 1814     Aditya Roy Kapoor               None               None  None  None
#
#      Star9     Genre1     Genre2     Genre3
# 0     None  Animation     Action  Adventure
# 1     None     Action      Crime      Drama
# 2     None     Action  Adventure      Drama
# 3     None     Action  Adventure     Sci-Fi
# 4     None     Action  Adventure      Drama
# ...    ...        ...        ...        ...
# 1810  None     Action      Crime   Thriller
# 1811  None     Action      Crime   Thriller
# 1812  None     Action    Fantasy     Sci-Fi
# 1813  None     Action      Crime      Drama
# 1814  None     Action      Drama       None
#
# [1815 rows x 33 columns]

# %%
# 2)   Display all movie names, Director, ratings, and gross collection where the genre is action.
query = """
SELECT directors.`Movie Name`, directors.Director1, directors.Director2, directors.Director3,
       directors.Director4, directors.Director5, directors.Director6, directors.Director7,
       directors.Director8, directors.Director9, directors.Ratings, stars.`Gross collection`
FROM directors
INNER JOIN stars ON directors.`Movie Name` = stars.`Movie Name`
WHERE stars.Genre1 = 'Action' OR stars.Genre2 = 'Action' OR stars.Genre3 = 'Action'
"""
df = pd.read_sql_query(query, conn)
df
# Out:
#                                              Movie Name           Director1  \
# 0                   Spider-Man: Across the Spider-Verse  Joaquim Dos Santos
# 1                                       The Dark Knight   Christopher Nolan
# 2         The Lord of the Rings: The Return of the King       Peter Jackson
# 3                                             Inception   Christopher Nolan
# 4     The Lord of the Rings: The Fellowship of the Ring       Peter Jackson
# ...                                                 ...                 ...
# 1810                                              Radhe         Prabhu Deva
# 1811                                             Race 3        Remo D'Souza
# 1812                                  Angels Apocalypse           Sean Cain
# 1813                                           Elk*rtuk       Keith English
# 1814                                            Sadak 2        Mahesh Bhatt
#
#               Director2             Director3      Director4  \
# 0           Kemp Powers    Justin K. Thompson  Shameik Moore
# 1        Christian Bale          Heath Ledger  Aaron Eckhart
# 2           Elijah Wood       Viggo Mortensen   Ian McKellen
# 3     Leonardo DiCaprio  Joseph Gordon-Levitt    Elliot Page
# 4           Elijah Wood          Ian McKellen  Orlando Bloom
# ...                 ...                   ...            ...
# 1810        Salman Khan          Disha Patani  Randeep Hooda
# 1811        Anil Kapoor           Salman Khan     Bobby Deol
# 1812      Enzo Zelocchi         Enzo Zelocchi  Jana Rochelle
# 1813  Vivianne Bánovits          András Mózes    Barna Bokor
# 1814         Alia Bhatt         Priyanka Bose    Sanjay Dutt
#
#                  Director5          Director6          Director7 Director8  \
# 0         Hailee Steinfeld  Brian Tyree Henry  Luna Lauren Velez      None
# 1            Michael Caine               None               None      None
# 2            Orlando Bloom               None               None      None
# 3             Ken Watanabe               None               None      None
# 4                Sean Bean               None               None      None
# ...                    ...                ...                ...       ...
# 1810         Jackie Shroff               None               None      None
# 1811  Jacqueline Fernandez               None               None      None
# 1812     Ryan C.F. Buckley    William Kirkham               None      None
# 1813       Gabriella Gubás               None               None      None
# 1814     Aditya Roy Kapoor               None               None      None
#
#      Director9  Ratings Gross collection
# 0         None      9.0            95163
# 1         None      9.0      534,858,444
# 2         None      9.0      377,845,905
# 3         None      8.8      292,576,195
# 4         None      8.8      315,544,750
# ...        ...      ...              ...
# 1810      None      1.9           178829
# 1811      None      1.9        1,690,861
# 1812      None      1.6            42914
# 1813      None      1.5            39505
# 1814      None      1.2            96269
#
# [1815 rows x 12 columns]

# %%
#3)      Display all details from both tables with the highest gross collection.
query = """
SELECT *
FROM Directors
INNER JOIN Stars ON Directors.`Movie Name` = Stars.`Movie Name`
WHERE Stars.`Gross collection` = (
    SELECT MAX(`Gross collection`)
    FROM Stars
)
"""
df = pd.read_sql_query(query, conn)
df
# Out:
#     Sno                 Movie Name  Duration  Year  Ratings  Metascore  \
# 0  1182  Hitman's Wife's Bodyguard       100  2021      6.1       32.0
#
#         Director1      Director2          Director3    Director4  ...  \
# 0  Patrick Hughes  Ryan Reynolds  Samuel L. Jackson  Salma Hayek  ...
#
#          Star3             Star4 Star5 Star6 Star7 Star8 Star9  Genre1  \
# 0  Salma Hayek  Antonio Banderas  None  None  None  None  None  Action
#
#    Genre2  Genre3
# 0  Comedy   Crime
#
# [1 rows x 33 columns]

# %%
#4)      Display all details from both tables with the highest ratings
query = """
SELECT *
FROM Directors
INNER JOIN Stars ON Directors.`Movie Name` = Stars.`Movie Name`
WHERE Directors.Ratings = (
    SELECT MAX(Ratings)
    FROM Directors
)
"""

df = pd.read_sql_query(query, conn)
df
# Out:
#    Sno                                     Movie Name  Duration  Year  \
# 0    1            Spider-Man: Across the Spider-Verse       140  2023
# 1    2                                The Dark Knight       152  2008
# 2    3  The Lord of the Rings: The Return of the King       201  2003
#
#    Ratings  Metascore           Director1       Director2           Director3  \
# 0      9.0       86.0  Joaquim Dos Santos     Kemp Powers  Justin K. Thompson
# 1      9.0       84.0   Christopher Nolan  Christian Bale        Heath Ledger
# 2      9.0       94.0       Peter Jackson     Elijah Wood     Viggo Mortensen
#
#        Director4  ...          Star3             Star4              Star5  \
# 0  Shameik Moore  ...  Shameik Moore  Hailee Steinfeld  Brian Tyree Henry
# 1  Aaron Eckhart  ...  Aaron Eckhart     Michael Caine               None
# 2   Ian McKellen  ...   Ian McKellen     Orlando Bloom               None
#
#                Star6 Star7 Star8 Star9     Genre1     Genre2     Genre3
# 0  Luna Lauren Velez  None  None  None  Animation     Action  Adventure
# 1               None  None  None  None     Action      Crime      Drama
# 2               None  None  None  None     Action  Adventure      Drama
#
# [3 rows x 33 columns]

# %%
#5)      Display all details from both tables with the lowest gross collection and lowest ratings
query = """
SELECT *
FROM Directors
INNER JOIN Stars ON Directors.`Movie Name` = Stars.`Movie Name`
WHERE Stars.`Gross collection` = (
    SELECT MIN(`Gross collection`)
    FROM Stars
)
OR Directors.Ratings = (
    SELECT MIN(Ratings)
    FROM Directors
)
"""

df = pd.read_sql_query(query, conn)
df
# Out:
#     Sno        Movie Name  Duration  Year  Ratings  Metascore     Director1  \
# 0  1366  Army of the Dead       148  2021      5.8       57.0   Zack Snyder
# 1  1753           Sadak 2       133  2020      1.2        NaN  Mahesh Bhatt
#
#        Director2      Director3          Director4  ...              Star3  \
# 0  Dave Bautista   Ella Purnell  Ana de la Reguera  ...  Ana de la Reguera
# 1     Alia Bhatt  Priyanka Bose        Sanjay Dutt  ...        Sanjay Dutt
#
#                Star4 Star5 Star6 Star7 Star8 Star9  Genre1 Genre2  Genre3
# 0     Omari Hardwick  None  None  None  None  None  Action  Crime   Drama
# 1  Aditya Roy Kapoor  None  None  None  None  None  Action  Drama    None
#
# [2 rows x 33 columns]

# %%
query = """
SELECT *
FROM Directors
INNER JOIN Stars ON Directors.`Movie Name` = Stars.`Movie Name`
WHERE Stars.`Gross collection` = (
    SELECT MIN(`Gross collection`)
    FROM Stars
)
and Directors.Ratings = (
    SELECT MIN(Ratings)
    FROM Directors
)
"""

df = pd.read_sql_query(query, conn)
df
# Out:
# Empty DataFrame
# Columns: [Sno, Movie Name, Duration, Year, Ratings, Metascore, Director1, Director2, Director3, Director4, Director5, Director6, Director7, Director8, Director9, Director10, Movie Name, Votes, Gross collection, Popularity, Certification, Star1, Star2, Star3, Star4, Star5, Star6, Star7, Star8, Star9, Genre1, Genre2, Genre3]
# Index: []
#
# [0 rows x 33 columns]

# %% [markdown]
# ### Query solutions using PANDAS SQL

# %%
import pandas as pd

# %%
# Read the directors.info CSV file into a DataFrame
directors_df = pd.read_csv(r"C:\Users\TCS\Desktop\Project\Capstone IMDB\directors_info.csv")

# %%
# Print the directors DataFrame
print(directors_df)
# Out:
#        Sno                                         Movie Name  Duration  Year  \
# 0        1                Spider-Man: Across the Spider-Verse       140  2023
# 1        2                                    The Dark Knight       152  2008
# 2        3      The Lord of the Rings: The Return of the King       201  2003
# 3        4                                          Inception       148  2010
# 4        5  The Lord of the Rings: The Fellowship of the Ring       178  2001
# ...    ...                                                ...       ...   ...
# 1748  1749                                              Radhe       109  2021
# 1749  1750                                             Race 3       160  2018
# 1750  1751                                  Angels Apocalypse        85  2015
# 1751  1752                                           Elk*rtuk       125  2021
# 1752  1753                                            Sadak 2       133  2020
#
#       Ratings  Metascore           Director1          Director2  \
# 0         9.0       86.0  Joaquim Dos Santos        Kemp Powers
# 1         9.0       84.0   Christopher Nolan     Christian Bale
# 2         9.0       94.0       Peter Jackson        Elijah Wood
# 3         8.8       74.0   Christopher Nolan  Leonardo DiCaprio
# 4         8.8       92.0       Peter Jackson        Elijah Wood
# ...       ...        ...                 ...                ...
# 1748      1.9        NaN         Prabhu Deva        Salman Khan
# 1749      1.9        NaN        Remo D'Souza        Anil Kapoor
# 1750      1.6        NaN           Sean Cain      Enzo Zelocchi
# 1751      1.5        NaN       Keith English  Vivianne Bánovits
# 1752      1.2        NaN        Mahesh Bhatt         Alia Bhatt
#
#                  Director3      Director4             Director5  \
# 0       Justin K. Thompson  Shameik Moore      Hailee Steinfeld
# 1             Heath Ledger  Aaron Eckhart         Michael Caine
# 2          Viggo Mortensen   Ian McKellen         Orlando Bloom
# 3     Joseph Gordon-Levitt    Elliot Page          Ken Watanabe
# 4             Ian McKellen  Orlando Bloom             Sean Bean
# ...                    ...            ...                   ...
# 1748          Disha Patani  Randeep Hooda         Jackie Shroff
# 1749           Salman Khan     Bobby Deol  Jacqueline Fernandez
# 1750         Enzo Zelocchi  Jana Rochelle     Ryan C.F. Buckley
# 1751          András Mózes    Barna Bokor       Gabriella Gubás
# 1752         Priyanka Bose    Sanjay Dutt     Aditya Roy Kapoor
#
#               Director6          Director7 Director8 Director9 Director10
# 0     Brian Tyree Henry  Luna Lauren Velez       NaN       NaN        NaN
# 1                   NaN                NaN       NaN       NaN        NaN
# 2                   NaN                NaN       NaN       NaN        NaN
# 3                   NaN                NaN       NaN       NaN        NaN
# 4                   NaN                NaN       NaN       NaN        NaN
# ...                 ...                ...       ...       ...        ...
# 1748                NaN                NaN       NaN       NaN        NaN
# 1749                NaN                NaN       NaN       NaN        NaN
# 1750    William Kirkham                NaN       NaN       NaN        NaN
# 1751                NaN                NaN       NaN       NaN        NaN
# 1752                NaN                NaN       NaN       NaN        NaN
#
# [1753 rows x 16 columns]

# %% [markdown]
# ### Table 1: Sno, MovieName, Director Name, Duration, genre, ratings

# %%
#1)  Display all the details of movies created by directors Christopher and Matt Reeves.

# Filter the DataFrame based on the directors' names
filtered_directors_df = directors_df[
    (directors_df['Director1'] == 'Christopher Nolan') |
    (directors_df['Director2'] == 'Christopher Nolan') |
    (directors_df['Director3'] == 'Christopher Nolan') |
    (directors_df['Director4'] == 'Christopher Nolan') |
    (directors_df['Director5'] == 'Christopher Nolan') |
    (directors_df['Director6'] == 'Christopher Nolan') |
    (directors_df['Director7'] == 'Christopher Nolan') |
    (directors_df['Director8'] == 'Christopher Nolan') |
    (directors_df['Director9'] == 'Christopher Nolan') |
    (directors_df['Director1'] == 'Matt Reeves') |
    (directors_df['Director2'] == 'Matt Reeves') |
    (directors_df['Director3'] == 'Matt Reeves') |
    (directors_df['Director4'] == 'Matt Reeves') |
    (directors_df['Director5'] == 'Matt Reeves') |
    (directors_df['Director6'] == 'Matt Reeves') |
    (directors_df['Director7'] == 'Matt Reeves') |
    (directors_df['Director8'] == 'Matt Reeves') |
    (directors_df['Director9'] == 'Matt Reeves')
]

# Print the filtered DataFrame
print(filtered_directors_df)
# Out:
#      Sno                      Movie Name  Duration  Year  Ratings  Metascore  \
# 1      2                 The Dark Knight       152  2008      9.0       84.0
# 3      4                       Inception       148  2010      8.8       74.0
# 21    22           The Dark Knight Rises       164  2012      8.4       78.0
# 41    42                   Batman Begins       140  2005      8.2       70.0
# 130  131                      The Batman       176  2022      7.8       72.0
# 136  137                         Dunkirk       106  2017      7.8       94.0
# 224  225  Dawn of the Planet of the Apes       130  2014      7.6       79.0
# 304  305  War for the Planet of the Apes       140  2017      7.4       82.0
# 321  322                           Tenet       150  2020      7.3       69.0
# 501  502                     Cloverfield        85  2008      7.0       64.0
#
#              Director1              Director2             Director3  \
# 1    Christopher Nolan         Christian Bale          Heath Ledger
# 3    Christopher Nolan      Leonardo DiCaprio  Joseph Gordon-Levitt
# 21   Christopher Nolan         Christian Bale             Tom Hardy
# 41   Christopher Nolan         Christian Bale         Michael Caine
# 130        Matt Reeves       Robert Pattinson           Zoë Kravitz
# 136  Christopher Nolan        Fionn Whitehead         Barry Keoghan
# 224        Matt Reeves            Gary Oldman          Keri Russell
# 304        Matt Reeves            Andy Serkis       Woody Harrelson
# 321  Christopher Nolan  John David Washington      Robert Pattinson
# 501        Matt Reeves             Mike Vogel         Jessica Lucas
#
#              Director4         Director5 Director6 Director7 Director8  \
# 1        Aaron Eckhart     Michael Caine       NaN       NaN       NaN
# 3          Elliot Page      Ken Watanabe       NaN       NaN       NaN
# 21       Anne Hathaway       Gary Oldman       NaN       NaN       NaN
# 41        Ken Watanabe       Liam Neeson       NaN       NaN       NaN
# 130     Jeffrey Wright     Colin Farrell       NaN       NaN       NaN
# 136       Mark Rylance         Tom Hardy       NaN       NaN       NaN
# 224        Andy Serkis  Kodi Smit-McPhee       NaN       NaN       NaN
# 304         Steve Zahn     Karin Konoval       NaN       NaN       NaN
# 321  Elizabeth Debicki      Juhan Ulfsak       NaN       NaN       NaN
# 501       Lizzy Caplan       T.J. Miller       NaN       NaN       NaN
#
#     Director9 Director10
# 1         NaN        NaN
# 3         NaN        NaN
# 21        NaN        NaN
# 41        NaN        NaN
# 130       NaN        NaN
# 136       NaN        NaN
# 224       NaN        NaN
# 304       NaN        NaN
# 321       NaN        NaN
# 501       NaN        NaN

# %%
#2) Display all the details of movies with a duration of 140 minutes to 190 minutes.
# Filter the DataFrame based on the duration range
filtered_directors_df = directors_df[
    (directors_df['Duration'] >= 140) & (directors_df['Duration'] <= 190)
]

# Print the filtered DataFrame
print(filtered_directors_df)
# Out:
#        Sno                                         Movie Name  Duration  Year  \
# 0        1                Spider-Man: Across the Spider-Verse       140  2023
# 1        2                                    The Dark Knight       152  2008
# 3        4                                          Inception       148  2010
# 4        5  The Lord of the Rings: The Fellowship of the Ring       178  2001
# 5        6              The Lord of the Rings: The Two Towers       179  2002
# ...    ...                                                ...       ...   ...
# 1739  1740                                             Gunday       152  2014
# 1740  1741                                              Liger       140  2022
# 1743  1744                                        Heropanti 2       145  2022
# 1744  1745                                             Laxmii       141  2020
# 1749  1750                                             Race 3       160  2018
#
#       Ratings  Metascore           Director1            Director2  \
# 0         9.0       86.0  Joaquim Dos Santos          Kemp Powers
# 1         9.0       84.0   Christopher Nolan       Christian Bale
# 3         8.8       74.0   Christopher Nolan    Leonardo DiCaprio
# 4         8.8       92.0       Peter Jackson          Elijah Wood
# 5         8.8       87.0       Peter Jackson          Elijah Wood
# ...       ...        ...                 ...                  ...
# 1739      2.7        NaN     Ali Abbas Zafar        Ranveer Singh
# 1740      2.7        NaN      Puri Jagannadh           Mike Tyson
# 1743      2.5        NaN          Ahmed Khan         Tiger Shroff
# 1744      2.5        NaN    Raghava Lawrence  Balakrishnan Thevar
# 1749      1.9        NaN        Remo D'Souza          Anil Kapoor
#
#                  Director3              Director4             Director5  \
# 0       Justin K. Thompson          Shameik Moore      Hailee Steinfeld
# 1             Heath Ledger          Aaron Eckhart         Michael Caine
# 3     Joseph Gordon-Levitt            Elliot Page          Ken Watanabe
# 4             Ian McKellen          Orlando Bloom             Sean Bean
# 5             Ian McKellen        Viggo Mortensen         Orlando Bloom
# ...                    ...                    ...                   ...
# 1739          Arjun Kapoor  Priyanka Chopra Jonas           Irrfan Khan
# 1740     Vijay Deverakonda          Ananya Panday        Ramya Krishnan
# 1743   Nawazuddin Siddiqui           Tara Sutaria     Amber Doig-Thorne
# 1744          Akshay Kumar           Kiara Advani         Sharad Kelkar
# 1749           Salman Khan             Bobby Deol  Jacqueline Fernandez
#
#               Director6          Director7 Director8 Director9 Director10
# 0     Brian Tyree Henry  Luna Lauren Velez       NaN       NaN        NaN
# 1                   NaN                NaN       NaN       NaN        NaN
# 3                   NaN                NaN       NaN       NaN        NaN
# 4                   NaN                NaN       NaN       NaN        NaN
# 5                   NaN                NaN       NaN       NaN        NaN
# ...                 ...                ...       ...       ...        ...
# 1739                NaN                NaN       NaN       NaN        NaN
# 1740                NaN                NaN       NaN       NaN        NaN
# 1743                NaN                NaN       NaN       NaN        NaN
# 1744   Ashwini Kalsekar                NaN       NaN       NaN        NaN
# 1749                NaN                NaN       NaN       NaN        NaN
#
# [204 rows x 16 columns]

# %%
# 3) Display all details of movies with ratings above 7 in ascending order.
# Filter the DataFrame based on ratings above 7
filtered_directors_df = directors_df[directors_df['Ratings'] > 7]

# Sort the DataFrame by ratings in ascending order
sorted_directors_df = filtered_directors_df.sort_values('Ratings', ascending=True)

# Print the sorted DataFrame
print(sorted_directors_df)
# Out:
#      Sno                                         Movie Name  Duration  Year  \
# 487  488                                     Gabbar Is Back       128  2015
# 454  455                               Flags of Our Fathers       135  2006
# 453  454                              Live Free or Die Hard       128  2007
# 452  453                                  Deepwater Horizon       107  2016
# 451  452                                          Desperado       104  1995
# ..   ...                                                ...       ...   ...
# 4      5  The Lord of the Rings: The Fellowship of the Ring       178  2001
# 3      4                                          Inception       148  2010
# 2      3      The Lord of the Rings: The Return of the King       201  2003
# 1      2                                    The Dark Knight       152  2008
# 0      1                Spider-Man: Across the Spider-Verse       140  2023
#
#      Ratings  Metascore                  Director1          Director2  \
# 487      7.1        NaN  Radha Krishna Jagarlamudi       Akshay Kumar
# 454      7.1       79.0             Clint Eastwood     Ryan Phillippe
# 453      7.1       69.0                Len Wiseman       Bruce Willis
# 452      7.1       68.0                 Peter Berg      Mark Wahlberg
# 451      7.1       55.0           Robert Rodriguez   Antonio Banderas
# ..       ...        ...                        ...                ...
# 4        8.8       92.0              Peter Jackson        Elijah Wood
# 3        8.8       74.0          Christopher Nolan  Leonardo DiCaprio
# 2        9.0       94.0              Peter Jackson        Elijah Wood
# 1        9.0       84.0          Christopher Nolan     Christian Bale
# 0        9.0       86.0         Joaquim Dos Santos        Kemp Powers
#
#                 Director3           Director4         Director5  \
# 487         Shruti Haasan      Kareena Kapoor             Suman
# 454          Barry Pepper        Joseph Cross    Jesse Bradford
# 453           Justin Long    Timothy Olyphant          Maggie Q
# 452          Kurt Russell  Douglas M. Griffin      James DuMont
# 451           Salma Hayek  Joaquim de Almeida      Cheech Marin
# ..                    ...                 ...               ...
# 4            Ian McKellen       Orlando Bloom         Sean Bean
# 3    Joseph Gordon-Levitt         Elliot Page      Ken Watanabe
# 2         Viggo Mortensen        Ian McKellen     Orlando Bloom
# 1            Heath Ledger       Aaron Eckhart     Michael Caine
# 0      Justin K. Thompson       Shameik Moore  Hailee Steinfeld
#
#              Director6          Director7 Director8 Director9 Director10
# 487                NaN                NaN       NaN       NaN        NaN
# 454                NaN                NaN       NaN       NaN        NaN
# 453                NaN                NaN       NaN       NaN        NaN
# 452                NaN                NaN       NaN       NaN        NaN
# 451                NaN                NaN       NaN       NaN        NaN
# ..                 ...                ...       ...       ...        ...
# 4                  NaN                NaN       NaN       NaN        NaN
# 3                  NaN                NaN       NaN       NaN        NaN
# 2                  NaN                NaN       NaN       NaN        NaN
# 1                  NaN                NaN       NaN       NaN        NaN
# 0    Brian Tyree Henry  Luna Lauren Velez       NaN       NaN        NaN
#
# [488 rows x 16 columns]

# %%
# 4) Display all movie names in descending order.
# Sort the DataFrame by movie names in descending order
sorted_directors_df = directors_df.sort_values('Movie Name', ascending=False)

# Reset the index of the DataFrame
sorted_directors_df = sorted_directors_df.reset_index(drop=True)

# Select only the Movie Name column
movie_names = sorted_directors_df['Movie Name']

# Print the movie names in descending order
print(movie_names)
# Out:
# 0                     Ölümlü Dünya
# 1                         Æon Flux
# 2          xXx: State of the Union
# 3       xXx: Return of Xander Cage
# 4                              xXx
#                    ...
# 1748                     12 Rounds
# 1749                     10,000 BC
# 1750               1 - Nenokkadine
# 1751                           '71
# 1752                     #Saraitda
# Name: Movie Name, Length: 1753, dtype: object

# %%
# 5) Display movie name starts with ‘P’ and their rating is greater than 7.
# Filter the DataFrame based on movie names starting with 'P' and rating greater than 7
filtered_directors_df = directors_df[
    (directors_df['Movie Name'].str.startswith('P')) & (directors_df['Ratings'] > 7)
]

# Select only the Movie Name column
movie_names = filtered_directors_df['Movie Name']

# Print the movie names
print(movie_names)
# Out:
# 56                                      Paan Singh Tomar
# 58     Pirates of the Caribbean: The Curse of the Bla...
# 118                              Per un pugno di dollari
# 141                                             Predator
# 191                                   Ponniyin Selvan: I
# 237                            Pushpa: The Rise - Part 1
# 292                                       Predestination
# 338           Pirates of the Caribbean: Dead Man's Chest
# 342                                         Patriots Day
# 379                                          Point Break
# 437                                                 Prey
# 441             Pirates of the Caribbean: At World's End
# 458                                        Planet Terror
# 469                                              Payback
# Name: Movie Name, dtype: object

# %% [markdown]
# ### Table 2: Movie Name, stars, votes, Genre, Gross collection, popularity, Certification

# %%
# Read the stars.info CSV file into a DataFrame
stars_df = pd.read_csv(r"C:\Users\TCS\Desktop\Project\Capstone IMDB\stars_info.csv")

# %%
# Print the stars DataFrame
print(stars_df)
# Out:
#                                              Movie Name    Votes  \
# 0                   Spider-Man: Across the Spider-Verse    95163
# 1                                       The Dark Knight  2722695
# 2         The Lord of the Rings: The Return of the King  1889533
# 3                                             Inception  2416660
# 4     The Lord of the Rings: The Fellowship of the Ring  1918116
# ...                                                 ...      ...
# 1748                                              Radhe   178829
# 1749                                             Race 3    47600
# 1750                                  Angels Apocalypse    42914
# 1751                                           Elk*rtuk    39505
# 1752                                            Sadak 2    96269
#
#      Gross collection  Popularity Certification              Star1  \
# 0               95163         9.0             U        Kemp Powers
# 1         534,858,444         9.0            UA     Christian Bale
# 2         377,845,905         9.0             U        Elijah Wood
# 3         292,576,195         8.8            UA  Leonardo DiCaprio
# 4         315,544,750         8.8             U        Elijah Wood
# ...               ...         ...           ...                ...
# 1748           178829         1.9            UA        Salman Khan
# 1749        1,690,861         1.9            UA        Anil Kapoor
# 1750            42914         1.6           NaN      Enzo Zelocchi
# 1751            39505         1.5           NaN  Vivianne Bánovits
# 1752            96269         1.2           15+         Alia Bhatt
#
#                      Star2          Star3                 Star4  \
# 0       Justin K. Thompson  Shameik Moore      Hailee Steinfeld
# 1             Heath Ledger  Aaron Eckhart         Michael Caine
# 2          Viggo Mortensen   Ian McKellen         Orlando Bloom
# 3     Joseph Gordon-Levitt    Elliot Page          Ken Watanabe
# 4             Ian McKellen  Orlando Bloom             Sean Bean
# ...                    ...            ...                   ...
# 1748          Disha Patani  Randeep Hooda         Jackie Shroff
# 1749           Salman Khan     Bobby Deol  Jacqueline Fernandez
# 1750         Enzo Zelocchi  Jana Rochelle     Ryan C.F. Buckley
# 1751          András Mózes    Barna Bokor       Gabriella Gubás
# 1752         Priyanka Bose    Sanjay Dutt     Aditya Roy Kapoor
#
#                   Star5              Star6 Star7 Star8 Star9     Genre1  \
# 0     Brian Tyree Henry  Luna Lauren Velez   NaN   NaN   NaN  Animation
# 1                   NaN                NaN   NaN   NaN   NaN     Action
# 2                   NaN                NaN   NaN   NaN   NaN     Action
# 3                   NaN                NaN   NaN   NaN   NaN     Action
# 4                   NaN                NaN   NaN   NaN   NaN     Action
# ...                 ...                ...   ...   ...   ...        ...
# 1748                NaN                NaN   NaN   NaN   NaN     Action
# 1749                NaN                NaN   NaN   NaN   NaN     Action
# 1750    William Kirkham                NaN   NaN   NaN   NaN     Action
# 1751                NaN                NaN   NaN   NaN   NaN     Action
# 1752                NaN                NaN   NaN   NaN   NaN     Action
#
#          Genre2     Genre3
# 0        Action  Adventure
# 1         Crime      Drama
# 2     Adventure      Drama
# 3     Adventure     Sci-Fi
# 4     Adventure      Drama
# ...         ...        ...
# 1748      Crime   Thriller
# 1749      Crime   Thriller
# 1750    Fantasy     Sci-Fi
# 1751      Crime      Drama
# 1752      Drama        NaN
#
# [1753 rows x 17 columns]

# %%
# 1) Display all movie names with star Arnold Schwarzenegger in ascending order.


# Create a list of the Star columns
star_columns = ['Star1', 'Star2', 'Star3', 'Star4', 'Star5', 'Star6', 'Star7', 'Star8', 'Star9']

# Reshape the DataFrame using pd.melt()
melted_df = pd.melt(stars_df, id_vars=['Movie Name'], value_vars=star_columns, var_name='Star Number', value_name='Star Name')

# Filter out missing values in the 'Star Name' column
filtered_df = melted_df.dropna(subset=['Star Name'])

# Filter the DataFrame based on movies with Arnold Schwarzenegger
filtered_df = filtered_df[filtered_df['Star Name'].str.contains('Arnold Schwarzenegger', case=False)]

# Sort the movie names in ascending order
sorted_movie_names = filtered_df['Movie Name'].sort_values(ascending=True)

# Print the movie names in ascending order
for movie_name in sorted_movie_names:
    print(movie_name)
# Out:
# Batman & Robin
# Collateral Damage
# Commando
# Conan the Barbarian
# Conan the Destroyer
# End of Days
# Eraser
# Escape Plan
# Kindergarten Cop
# Last Action Hero
# Predator
# Raw Deal
# Red Heat
# Red Sonja
# Sabotage
# Terminator 2: Judgment Day
# Terminator 3: Rise of the Machines
# Terminator Genisys
# Terminator: Dark Fate
# The 6th Day
# The Last Stand
# The Running Man
# The Terminator
# Total Recall
# True Lies

# %%
#2) Display all details of the movie with the highest number of votes
# Find the row with the highest number of votes
max_votes_row = stars_df.loc[stars_df['Votes'].idxmax()]

# Print all the details of the movie with the highest number of votes
print(max_votes_row)
# Out:
# Movie Name          The Dark Knight
# Votes                       2722695
# Gross collection        534,858,444
# Popularity                      9.0
# Certification                    UA
# Star1                Christian Bale
# Star2                  Heath Ledger
# Star3                 Aaron Eckhart
# Star4                 Michael Caine
# Star5                           NaN
# Star6                           NaN
# Star7                           NaN
# Star8                           NaN
# Star9                           NaN
# Genre1                       Action
# Genre2                        Crime
# Genre3                        Drama
# Name: 1, dtype: object

# %%
#3) Display movie names with gross collections in descending order.
# Sort the DataFrame by 'Gross collection' column in descending order
sorted_df = stars_df.sort_values('Gross collection', ascending=False)

# Display the movie names with gross collections in descending order
movie_names = sorted_df['Movie Name']
print(movie_names)
# Out:
# 1181          Hitman's Wife's Bodyguard
# 47                   Gangs of Wasseypur
# 863                  Olympus Has Fallen
# 1399                   The Green Hornet
# 54                         Sherlock Jr.
#                      ...
# 585                   Love and Monsters
# 69                          The General
# 710                    Attack the Block
# 159     Cowboy Bebop: Tengoku no tobira
# 1365                   Army of the Dead
# Name: Movie Name, Length: 1753, dtype: object

# %%
# 4) Display the gross collection of movies with the star Arnold
# Filter the DataFrame to include only rows where any of the Star columns contain "Arnold"
filtered_df = stars_df.loc[
    (stars_df['Star1'].str.contains('Arnold', na=False)) |
    (stars_df['Star2'].str.contains('Arnold', na=False)) |
    (stars_df['Star3'].str.contains('Arnold', na=False)) |
    (stars_df['Star4'].str.contains('Arnold', na=False)) |
    (stars_df['Star5'].str.contains('Arnold', na=False)) |
    (stars_df['Star6'].str.contains('Arnold', na=False)) |
    (stars_df['Star7'].str.contains('Arnold', na=False)) |
    (stars_df['Star8'].str.contains('Arnold', na=False)) |
    (stars_df['Star9'].str.contains('Arnold', na=False))
]

# Display the gross collection of movies with Arnold
gross_collections = filtered_df['Gross collection']
print(gross_collections)
# Out:
# 10      204,843,350
# 61       38,400,000
# 141      59,735,548
# 252     119,394,840
# 323     146,282,411
# 430     155,247,825
# 565      39,565,475
# 672      35,100,000
# 701      25,132,228
# 753      38,122,105
# 917      50,016,394
# 918     202,019,785
# 996      89,760,956
# 1005     12,050,299
# 1011    150,371,112
# 1071     91,457,688
# 1073     62,253,077
# 1107    101,295,562
# 1212     34,994,648
# 1313     31,042,035
# 1329     34,604,280
# 1375     66,889,043
# 1452     10,508,518
# 1496     16,209,459
# 1543     40,077,257
# 1637      6,948,633
# 1726    107,325,195
# Name: Gross collection, dtype: object

# %%
# 5) Display all details of movies with comedy and action genres.
# Filter the DataFrame to include only rows with comedy and action genres
filtered_df = stars_df[
    (stars_df['Genre1'] == 'Comedy') | (stars_df['Genre2'] == 'Comedy') | (stars_df['Genre3'] == 'Comedy')
    & (stars_df['Genre1'] == 'Action') | (stars_df['Genre2'] == 'Action') | (stars_df['Genre3'] == 'Action')
]

# Display all the details of movies with comedy and action genres
print(filtered_df)
# Out:
#                                        Movie Name   Votes Gross collection  \
# 0             Spider-Man: Across the Spider-Verse   95163            95163
# 16              Spider-Man: Into the Spider-Verse  580076      190,241,310
# 29                                  Mononoke-hime  407422        2,375,308
# 36                 Guardians of the Galaxy Vol. 3  164600           164600
# 45             Kimetsu no Yaiba: Mugen Ressha-Hen   64706       47,700,000
# ...                                           ...     ...              ...
# 1725                 The Adventures of Pluto Nash   26472        4,420,080
# 1727  The Adventures of Sharkboy and Lavagirl 3-D   40053       39,177,684
# 1733        Spy Kids 4: All the Time in the World   27006       38,538,188
# 1743                                  Heropanti 2   26997            26997
# 1744                                       Laxmii   57994            57994
#
#       Popularity Certification                Star1                Star2  \
# 0            9.0             U          Kemp Powers   Justin K. Thompson
# 16           8.4             U         Peter Ramsey       Rodney Rothman
# 29           8.3             U         Yôji Matsuda        Yuriko Ishida
# 36           8.2            UA          Chris Pratt       Chukwudi Iwuji
# 45           8.2            UA        Natsuki Hanae           Akari Kitô
# ...          ...           ...                  ...                  ...
# 1725         3.8         PG-13         Eddie Murphy             Jay Mohr
# 1727         3.7             U          Cayden Boyd         George Lopez
# 1733         3.5            PG         Jessica Alba         Jeremy Piven
# 1743         2.5            UA         Tiger Shroff  Nawazuddin Siddiqui
# 1744         2.5        UA 16+  Balakrishnan Thevar         Akshay Kumar
#
#                     Star3              Star4              Star5  \
# 0           Shameik Moore   Hailee Steinfeld  Brian Tyree Henry
# 16          Shameik Moore       Jake Johnson   Hailee Steinfeld
# 29            Yûko Tanaka       Billy Crudup                NaN
# 36         Bradley Cooper    Pom Klementieff                NaN
# 45    Yoshitsugu Matsuoka       Hiro Shimono                NaN
# ...                   ...                ...                ...
# 1725          Randy Quaid     Rosario Dawson                NaN
# 1727        Kristin Davis     David Arquette                NaN
# 1733          Joel McHale    Rowan Blanchard                NaN
# 1743         Tara Sutaria  Amber Doig-Thorne                NaN
# 1744         Kiara Advani      Sharad Kelkar   Ashwini Kalsekar
#
#                   Star6 Star7 Star8 Star9     Genre1     Genre2     Genre3
# 0     Luna Lauren Velez   NaN   NaN   NaN  Animation     Action  Adventure
# 16       Mahershala Ali   NaN   NaN   NaN  Animation     Action  Adventure
# 29                  NaN   NaN   NaN   NaN  Animation     Action  Adventure
# 36                  NaN   NaN   NaN   NaN     Action  Adventure     Comedy
# 45                  NaN   NaN   NaN   NaN  Animation     Action  Adventure
# ...                 ...   ...   ...   ...        ...        ...        ...
# 1725                NaN   NaN   NaN   NaN     Action     Comedy     Sci-Fi
# 1727                NaN   NaN   NaN   NaN     Action  Adventure     Comedy
# 1733                NaN   NaN   NaN   NaN     Action  Adventure     Comedy
# 1743                NaN   NaN   NaN   NaN     Action     Comedy      Crime
# 1744                NaN   NaN   NaN   NaN     Action     Comedy     Horror
#
# [440 rows x 17 columns]

# %% [markdown]
# #### Make subquery :

# %%
# 1) Display all details from both tables where movie names are the same.
# Perform an inner join on the "Movie Name" column
merged_df = pd.merge(directors_df, stars_df, on='Movie Name', how='inner')

# Display all the details where movie names are the same
print(merged_df)
# Out:
#        Sno                                         Movie Name  Duration  Year  \
# 0        1                Spider-Man: Across the Spider-Verse       140  2023
# 1        2                                    The Dark Knight       152  2008
# 2        3      The Lord of the Rings: The Return of the King       201  2003
# 3        4                                          Inception       148  2010
# 4        5  The Lord of the Rings: The Fellowship of the Ring       178  2001
# ...    ...                                                ...       ...   ...
# 1810  1749                                              Radhe       109  2021
# 1811  1750                                             Race 3       160  2018
# 1812  1751                                  Angels Apocalypse        85  2015
# 1813  1752                                           Elk*rtuk       125  2021
# 1814  1753                                            Sadak 2       133  2020
#
#       Ratings  Metascore           Director1          Director2  \
# 0         9.0       86.0  Joaquim Dos Santos        Kemp Powers
# 1         9.0       84.0   Christopher Nolan     Christian Bale
# 2         9.0       94.0       Peter Jackson        Elijah Wood
# 3         8.8       74.0   Christopher Nolan  Leonardo DiCaprio
# 4         8.8       92.0       Peter Jackson        Elijah Wood
# ...       ...        ...                 ...                ...
# 1810      1.9        NaN         Prabhu Deva        Salman Khan
# 1811      1.9        NaN        Remo D'Souza        Anil Kapoor
# 1812      1.6        NaN           Sean Cain      Enzo Zelocchi
# 1813      1.5        NaN       Keith English  Vivianne Bánovits
# 1814      1.2        NaN        Mahesh Bhatt         Alia Bhatt
#
#                  Director3      Director4  ...          Star3  \
# 0       Justin K. Thompson  Shameik Moore  ...  Shameik Moore
# 1             Heath Ledger  Aaron Eckhart  ...  Aaron Eckhart
# 2          Viggo Mortensen   Ian McKellen  ...   Ian McKellen
# 3     Joseph Gordon-Levitt    Elliot Page  ...    Elliot Page
# 4             Ian McKellen  Orlando Bloom  ...  Orlando Bloom
# ...                    ...            ...  ...            ...
# 1810          Disha Patani  Randeep Hooda  ...  Randeep Hooda
# 1811           Salman Khan     Bobby Deol  ...     Bobby Deol
# 1812         Enzo Zelocchi  Jana Rochelle  ...  Jana Rochelle
# 1813          András Mózes    Barna Bokor  ...    Barna Bokor
# 1814         Priyanka Bose    Sanjay Dutt  ...    Sanjay Dutt
#
#                      Star4              Star5              Star6 Star7 Star8  \
# 0         Hailee Steinfeld  Brian Tyree Henry  Luna Lauren Velez   NaN   NaN
# 1            Michael Caine                NaN                NaN   NaN   NaN
# 2            Orlando Bloom                NaN                NaN   NaN   NaN
# 3             Ken Watanabe                NaN                NaN   NaN   NaN
# 4                Sean Bean                NaN                NaN   NaN   NaN
# ...                    ...                ...                ...   ...   ...
# 1810         Jackie Shroff                NaN                NaN   NaN   NaN
# 1811  Jacqueline Fernandez                NaN                NaN   NaN   NaN
# 1812     Ryan C.F. Buckley    William Kirkham                NaN   NaN   NaN
# 1813       Gabriella Gubás                NaN                NaN   NaN   NaN
# 1814     Aditya Roy Kapoor                NaN                NaN   NaN   NaN
#
#       Star9     Genre1     Genre2     Genre3
# 0       NaN  Animation     Action  Adventure
# 1       NaN     Action      Crime      Drama
# 2       NaN     Action  Adventure      Drama
# 3       NaN     Action  Adventure     Sci-Fi
# 4       NaN     Action  Adventure      Drama
# ...     ...        ...        ...        ...
# 1810    NaN     Action      Crime   Thriller
# 1811    NaN     Action      Crime   Thriller
# 1812    NaN     Action    Fantasy     Sci-Fi
# 1813    NaN     Action      Crime      Drama
# 1814    NaN     Action      Drama        NaN
#
# [1815 rows x 32 columns]

# %%
# 2)   Display all movie names, Director, ratings, and gross collection where the genre is action.

# Filter the stars DataFrame to include only rows with "Action" genre
action_movies = stars_df[
    (stars_df['Genre1'].str.lower() == 'action') |
    (stars_df['Genre2'].str.lower() == 'action') |
    (stars_df['Genre3'].str.lower() == 'action')
]

# Merge the directors and stars DataFrames on the 'Movie Name' column
merged_df = pd.merge(directors_df, action_movies, on='Movie Name', how='inner')

# Select the desired columns
desired_columns = ['Movie Name', 'Director1', 'Director2', 'Director3', 'Director4', 'Director5',
                   'Director6', 'Director7', 'Director8', 'Director9', 'Director10', 'Ratings', 'Gross collection']
result_df = merged_df[desired_columns]

# Display the result
print(result_df)
# Out:
#                                              Movie Name           Director1  \
# 0                   Spider-Man: Across the Spider-Verse  Joaquim Dos Santos
# 1                                       The Dark Knight   Christopher Nolan
# 2         The Lord of the Rings: The Return of the King       Peter Jackson
# 3                                             Inception   Christopher Nolan
# 4     The Lord of the Rings: The Fellowship of the Ring       Peter Jackson
# ...                                                 ...                 ...
# 1810                                              Radhe         Prabhu Deva
# 1811                                             Race 3        Remo D'Souza
# 1812                                  Angels Apocalypse           Sean Cain
# 1813                                           Elk*rtuk       Keith English
# 1814                                            Sadak 2        Mahesh Bhatt
#
#               Director2             Director3      Director4  \
# 0           Kemp Powers    Justin K. Thompson  Shameik Moore
# 1        Christian Bale          Heath Ledger  Aaron Eckhart
# 2           Elijah Wood       Viggo Mortensen   Ian McKellen
# 3     Leonardo DiCaprio  Joseph Gordon-Levitt    Elliot Page
# 4           Elijah Wood          Ian McKellen  Orlando Bloom
# ...                 ...                   ...            ...
# 1810        Salman Khan          Disha Patani  Randeep Hooda
# 1811        Anil Kapoor           Salman Khan     Bobby Deol
# 1812      Enzo Zelocchi         Enzo Zelocchi  Jana Rochelle
# 1813  Vivianne Bánovits          András Mózes    Barna Bokor
# 1814         Alia Bhatt         Priyanka Bose    Sanjay Dutt
#
#                  Director5          Director6          Director7 Director8  \
# 0         Hailee Steinfeld  Brian Tyree Henry  Luna Lauren Velez       NaN
# 1            Michael Caine                NaN                NaN       NaN
# 2            Orlando Bloom                NaN                NaN       NaN
# 3             Ken Watanabe                NaN                NaN       NaN
# 4                Sean Bean                NaN                NaN       NaN
# ...                    ...                ...                ...       ...
# 1810         Jackie Shroff                NaN                NaN       NaN
# 1811  Jacqueline Fernandez                NaN                NaN       NaN
# 1812     Ryan C.F. Buckley    William Kirkham                NaN       NaN
# 1813       Gabriella Gubás                NaN                NaN       NaN
# 1814     Aditya Roy Kapoor                NaN                NaN       NaN
#
#      Director9 Director10  Ratings Gross collection
# 0          NaN        NaN      9.0            95163
# 1          NaN        NaN      9.0      534,858,444
# 2          NaN        NaN      9.0      377,845,905
# 3          NaN        NaN      8.8      292,576,195
# 4          NaN        NaN      8.8      315,544,750
# ...        ...        ...      ...              ...
# 1810       NaN        NaN      1.9           178829
# 1811       NaN        NaN      1.9        1,690,861
# 1812       NaN        NaN      1.6            42914
# 1813       NaN        NaN      1.5            39505
# 1814       NaN        NaN      1.2            96269
#
# [1815 rows x 13 columns]

# %%
# 3)      Display all details from both tables with the highest gross collection

# Merge the directors and stars DataFrames on the 'Movie Name' column
merged_df = pd.merge(directors_df, stars_df, on='Movie Name', how='inner')

# Get the movie(s) with the highest gross collection
max_gross = merged_df['Gross collection'].max()
highest_gross_movies = merged_df[merged_df['Gross collection'] == max_gross]

# Display all the details for the movie(s) with the highest gross collection
print(highest_gross_movies)
# Out:
#        Sno                 Movie Name  Duration  Year  Ratings  Metascore  \
# 1254  1182  Hitman's Wife's Bodyguard       100  2021      6.1       32.0
#
#            Director1      Director2          Director3    Director4  ...  \
# 1254  Patrick Hughes  Ryan Reynolds  Samuel L. Jackson  Salma Hayek  ...
#
#             Star3             Star4 Star5 Star6 Star7 Star8  Star9  Genre1  \
# 1254  Salma Hayek  Antonio Banderas   NaN   NaN   NaN   NaN    NaN  Action
#
#       Genre2 Genre3
# 1254  Comedy  Crime
#
# [1 rows x 32 columns]

# %%
# 4)      Display all details from both tables with the highest ratings
# Merge the directors and stars DataFrames on the 'Movie Name' column
merged_df = pd.merge(directors_df, stars_df, on='Movie Name', how='inner')

# Get the movie(s) with the highest ratings
max_ratings = merged_df['Ratings'].max()
highest_rated_movies = merged_df[merged_df['Ratings'] == max_ratings]

# Display all the details for the movie(s) with the highest ratings
print(highest_rated_movies)
# Out:
#    Sno                                     Movie Name  Duration  Year  \
# 0    1            Spider-Man: Across the Spider-Verse       140  2023
# 1    2                                The Dark Knight       152  2008
# 2    3  The Lord of the Rings: The Return of the King       201  2003
#
#    Ratings  Metascore           Director1       Director2           Director3  \
# 0      9.0       86.0  Joaquim Dos Santos     Kemp Powers  Justin K. Thompson
# 1      9.0       84.0   Christopher Nolan  Christian Bale        Heath Ledger
# 2      9.0       94.0       Peter Jackson     Elijah Wood     Viggo Mortensen
#
#        Director4  ...          Star3             Star4              Star5  \
# 0  Shameik Moore  ...  Shameik Moore  Hailee Steinfeld  Brian Tyree Henry
# 1  Aaron Eckhart  ...  Aaron Eckhart     Michael Caine                NaN
# 2   Ian McKellen  ...   Ian McKellen     Orlando Bloom                NaN
#
#                Star6 Star7 Star8  Star9     Genre1     Genre2     Genre3
# 0  Luna Lauren Velez   NaN   NaN    NaN  Animation     Action  Adventure
# 1                NaN   NaN   NaN    NaN     Action      Crime      Drama
# 2                NaN   NaN   NaN    NaN     Action  Adventure      Drama
#
# [3 rows x 32 columns]

# %%
#5)      Display all details from both tables with the lowest gross collection and lowest ratings


# Merge the directors and stars DataFrames on the 'Movie Name' column
merged_df = pd.merge(directors_df, stars_df, on='Movie Name', how='inner')

# Get the movie(s) with the lowest gross collection and lowest ratings
min_gross = merged_df['Gross collection'].min()
min_ratings = merged_df['Ratings'].min()

lowest_gross_movies = merged_df[merged_df['Gross collection'] == min_gross]
lowest_ratings_movies = merged_df[merged_df['Ratings'] == min_ratings]

# Display all the details for the movie(s) with the lowest gross collection
print("Movies with the lowest gross collection:")
print(lowest_gross_movies)

# Display all the details for the movie(s) with the lowest ratings
print("Movies with the lowest ratings:")
print(lowest_ratings_movies)
# Out:
# Movies with the lowest gross collection:
#        Sno        Movie Name  Duration  Year  Ratings  Metascore    Director1  \
# 1435  1366  Army of the Dead       148  2021      5.8       57.0  Zack Snyder
#
#           Director2     Director3          Director4  ...              Star3  \
# 1435  Dave Bautista  Ella Purnell  Ana de la Reguera  ...  Ana de la Reguera
#
#                Star4 Star5 Star6 Star7 Star8  Star9  Genre1  Genre2 Genre3
# 1435  Omari Hardwick   NaN   NaN   NaN   NaN    NaN  Action   Crime  Drama
#
# [1 rows x 32 columns]
# Movies with the lowest ratings:
#        Sno Movie Name  Duration  Year  Ratings  Metascore     Director1  \
# 1814  1753    Sadak 2       133  2020      1.2        NaN  Mahesh Bhatt
#
#        Director2      Director3    Director4  ...        Star3  \
# 1814  Alia Bhatt  Priyanka Bose  Sanjay Dutt  ...  Sanjay Dutt
#
#                   Star4 Star5 Star6 Star7 Star8  Star9  Genre1  Genre2 Genre3
# 1814  Aditya Roy Kapoor   NaN   NaN   NaN   NaN    NaN  Action   Drama    NaN
#
# [1 rows x 32 columns]
